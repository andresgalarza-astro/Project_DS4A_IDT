# %%
# !pip install seaborn

# %%
# !pip install openpyxl

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy                 as np
import geopandas             as gpd
import seaborn               as sns
import folium  #needed for interactive map
from folium.plugins import HeatMap
# %matplotlib inline
sns.set()
# Out:
# D:\JUAN CAMILO\Anaconda\envs\geo_env\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn(

# %% [markdown]
# # Carga geojson

# %%
file_path= 'D:/JUAN CAMILO/DS4A/Proyecto FInal/locashp/Loca.shp'
file_path2='D:/JUAN CAMILO/DS4A/Proyecto FInal/Bases de Datos/Mauricio Ospina - Instituto Distrital Turismo_Reto Observatorio de Turismo_Mauricio Ospina/9. Base de las rutas de transporte e Bogotá (2021)- Estación Troncal.xlsx'

# %%
MapaLocalidades = gpd.read_file(file_path)
MapaLocalidades
# Out:
#              LocNombre                            LocAAdmini       LocArea  \
# 0       ANTONIO NARIÑO                   Acuerdo 117 de 2003  4.879543e+06
# 1           TUNJUELITO                   Acuerdo 117 de 2003  9.910940e+06
# 2   RAFAEL URIBE URIBE                   Acuerdo 117 de 2003  1.383408e+07
# 3           CANDELARIA                   Acuerdo 117 de 2003  2.060243e+06
# 4       BARRIOS UNIDOS                     Acuerdo 8 de 1977  1.190345e+07
# 5          TEUSAQUILLO                     Acuerdo 8 de 1977  1.419317e+07
# 6        PUENTE ARANDA                     Acuerdo 8 de 1977  1.731115e+07
# 7         LOS MARTIRES                     Acuerdo 8 de 1977  6.514046e+06
# 8              SUMAPAZ                     Acuerdo 9 de 1986  7.809688e+08
# 9              USAQUEN  Acuerdo 8 de 1977 y Res 1751 de 2016  6.520141e+07
# 10           CHAPINERO  Acuerdo 8 de 1977 y Res 1751 de 2016  3.800891e+07
# 11            SANTA FE                   Acuerdo 117 de 2003  4.517065e+07
# 12       SAN CRISTOBAL                   Acuerdo 117 de 2003  4.909855e+07
# 13                USME                    Acuerdo 15 de 1993  2.150667e+08
# 14      CIUDAD BOLIVAR                    Acuerdo 14 de 1983  1.300026e+08
# 15                BOSA                    Acuerdo 14 de 1983  2.393320e+07
# 16             KENNEDY                     Acuerdo 8 de 1977  3.858973e+07
# 17            FONTIBON                     Acuerdo 8 de 1977  3.328100e+07
# 18            ENGATIVA                     Acuerdo 8 de 1977  3.588097e+07
# 19                SUBA                     Acuerdo 8 de 1977  1.005605e+08
#
#    LocCodigo  SHAPE_Leng  SHAPE_Area  \
# 0         15    0.108973    0.000397
# 1         06    0.210542    0.000807
# 2         18    0.174513    0.001126
# 3         17    0.067158    0.000168
# 4         12    0.121180    0.000969
# 5         13    0.148314    0.001156
# 6         16    0.161116    0.001410
# 7         14    0.099382    0.000530
# 8         20    1.914949    0.063549
# 9         01    0.436907    0.005310
# 10        02    0.333966    0.003095
# 11        03    0.395052    0.003678
# 12        04    0.363689    0.003998
# 13        05    0.982969    0.017508
# 14        19    0.702136    0.010585
# 15        07    0.307901    0.001949
# 16        08    0.283582    0.003143
# 17        09    0.321915    0.002710
# 18        10    0.291966    0.002922
# 19        11    0.592875    0.008191
#
#                                              geometry
# 0   POLYGON ((-74.13075 4.59335, -74.12917 4.59327...
# 1   POLYGON ((-74.13777 4.59489, -74.13165 4.59363...
# 2   POLYGON ((-74.12803 4.59254, -74.12777 4.59233...
# 3   POLYGON ((-74.06621 4.60317, -74.06620 4.60317...
# 4   POLYGON ((-74.05725 4.68684, -74.06249 4.65594...
# 5   POLYGON ((-74.09372 4.66607, -74.09332 4.66574...
# 6   POLYGON ((-74.11830 4.63741, -74.11504 4.64053...
# 7   POLYGON ((-74.07283 4.61542, -74.07311 4.61480...
# 8   POLYGON ((-74.20584 4.26966, -74.20584 4.26966...
# 9   POLYGON ((-74.01116 4.66459, -74.01117 4.66460...
# 10  POLYGON ((-74.01116 4.66459, -74.01154 4.66461...
# 11  POLYGON ((-73.99446 4.61425, -73.99457 4.61414...
# 12  POLYGON ((-74.02900 4.55830, -74.02930 4.55821...
# 13  POLYGON ((-74.05597 4.50832, -74.05611 4.50822...
# 14  POLYGON ((-74.21092 4.38691, -74.21114 4.38750...
# 15  POLYGON ((-74.18567 4.64705, -74.18480 4.64497...
# 16  POLYGON ((-74.18567 4.64705, -74.18527 4.64699...
# 17  POLYGON ((-74.15857 4.66274, -74.15848 4.66279...
# 18  POLYGON ((-74.15547 4.71798, -74.15547 4.71798...
# 19  POLYGON ((-74.03450 4.82547, -74.03478 4.82418...

# %%
dic_Localidades={'TEUSAQUILLO':'Teusaquillo',
                'USAQUEN':'Usaquén',
                'CHAPINERO':'Chapinero',
                'SANTA FE':'Santa Fe',
                'SAN CRISTOBAL':'San Cristobal',
                'USME':'Usme',
                'TUNJUELITO':'Tunjuelito',
                'BOSA':'Bosa',
                'KENNEDY':'Kennedy',
                'FONTIBON':'Fontibón',
                'ENGATIVA':'Engativá',
                'SUBA':'Suba',
                'BARRIOS UNIDOS':'Barrios Unidos',
                'TEUSAQUILLO':'Teusaquillo',
                'LOS MARTIRES':'Los Mártires',
                'ANTONIO NARIÑO':'Antonio Nariño',
                'PUENTE ARANDA':'Puente Aranda',
                'CANDELARIA':'La Candelaria',
                'RAFAEL URIBE URIBE':'Rafael Uribe Uribe',
                'CIUDAD BOLIVAR':'Ciudad Bolivar',
                 'SUMAPAZ':'Sumapaz'
}

# %%
MapaLocalidades['Nombre_Localidad']=MapaLocalidades['LocNombre'].replace(dic_Localidades)
MapaLocalidades['geometry2']=MapaLocalidades['geometry']
MapaLocalidades
# Out:
#              LocNombre                            LocAAdmini       LocArea  \
# 0       ANTONIO NARIÑO                   Acuerdo 117 de 2003  4.879543e+06
# 1           TUNJUELITO                   Acuerdo 117 de 2003  9.910940e+06
# 2   RAFAEL URIBE URIBE                   Acuerdo 117 de 2003  1.383408e+07
# 3           CANDELARIA                   Acuerdo 117 de 2003  2.060243e+06
# 4       BARRIOS UNIDOS                     Acuerdo 8 de 1977  1.190345e+07
# 5          TEUSAQUILLO                     Acuerdo 8 de 1977  1.419317e+07
# 6        PUENTE ARANDA                     Acuerdo 8 de 1977  1.731115e+07
# 7         LOS MARTIRES                     Acuerdo 8 de 1977  6.514046e+06
# 8              SUMAPAZ                     Acuerdo 9 de 1986  7.809688e+08
# 9              USAQUEN  Acuerdo 8 de 1977 y Res 1751 de 2016  6.520141e+07
# 10           CHAPINERO  Acuerdo 8 de 1977 y Res 1751 de 2016  3.800891e+07
# 11            SANTA FE                   Acuerdo 117 de 2003  4.517065e+07
# 12       SAN CRISTOBAL                   Acuerdo 117 de 2003  4.909855e+07
# 13                USME                    Acuerdo 15 de 1993  2.150667e+08
# 14      CIUDAD BOLIVAR                    Acuerdo 14 de 1983  1.300026e+08
# 15                BOSA                    Acuerdo 14 de 1983  2.393320e+07
# 16             KENNEDY                     Acuerdo 8 de 1977  3.858973e+07
# 17            FONTIBON                     Acuerdo 8 de 1977  3.328100e+07
# 18            ENGATIVA                     Acuerdo 8 de 1977  3.588097e+07
# 19                SUBA                     Acuerdo 8 de 1977  1.005605e+08
#
#    LocCodigo  SHAPE_Leng  SHAPE_Area  \
# 0         15    0.108973    0.000397
# 1         06    0.210542    0.000807
# 2         18    0.174513    0.001126
# 3         17    0.067158    0.000168
# 4         12    0.121180    0.000969
# 5         13    0.148314    0.001156
# 6         16    0.161116    0.001410
# 7         14    0.099382    0.000530
# 8         20    1.914949    0.063549
# 9         01    0.436907    0.005310
# 10        02    0.333966    0.003095
# 11        03    0.395052    0.003678
# 12        04    0.363689    0.003998
# 13        05    0.982969    0.017508
# 14        19    0.702136    0.010585
# 15        07    0.307901    0.001949
# 16        08    0.283582    0.003143
# 17        09    0.321915    0.002710
# 18        10    0.291966    0.002922
# 19        11    0.592875    0.008191
#
#                                              geometry    Nombre_Localidad  \
# 0   POLYGON ((-74.13075 4.59335, -74.12917 4.59327...      Antonio Nariño
# 1   POLYGON ((-74.13777 4.59489, -74.13165 4.59363...          Tunjuelito
# 2   POLYGON ((-74.12803 4.59254, -74.12777 4.59233...  Rafael Uribe Uribe
# 3   POLYGON ((-74.06621 4.60317, -74.06620 4.60317...       La Candelaria
# 4   POLYGON ((-74.05725 4.68684, -74.06249 4.65594...      Barrios Unidos
# 5   POLYGON ((-74.09372 4.66607, -74.09332 4.66574...         Teusaquillo
# 6   POLYGON ((-74.11830 4.63741, -74.11504 4.64053...       Puente Aranda
# 7   POLYGON ((-74.07283 4.61542, -74.07311 4.61480...        Los Mártires
# 8   POLYGON ((-74.20584 4.26966, -74.20584 4.26966...             Sumapaz
# 9   POLYGON ((-74.01116 4.66459, -74.01117 4.66460...             Usaquén
# 10  POLYGON ((-74.01116 4.66459, -74.01154 4.66461...           Chapinero
# 11  POLYGON ((-73.99446 4.61425, -73.99457 4.61414...            Santa Fe
# 12  POLYGON ((-74.02900 4.55830, -74.02930 4.55821...       San Cristobal
# 13  POLYGON ((-74.05597 4.50832, -74.05611 4.50822...                Usme
# 14  POLYGON ((-74.21092 4.38691, -74.21114 4.38750...      Ciudad Bolivar
# 15  POLYGON ((-74.18567 4.64705, -74.18480 4.64497...                Bosa
# 16  POLYGON ((-74.18567 4.64705, -74.18527 4.64699...             Kennedy
# 17  POLYGON ((-74.15857 4.66274, -74.15848 4.66279...            Fontibón
# 18  POLYGON ((-74.15547 4.71798, -74.15547 4.71798...            Engativá
# 19  POLYGON ((-74.03450 4.82547, -74.03478 4.82418...                Suba
#
#                                             geometry2
# 0   POLYGON ((-74.13075 4.59335, -74.12917 4.59327...
# 1   POLYGON ((-74.13777 4.59489, -74.13165 4.59363...
# 2   POLYGON ((-74.12803 4.59254, -74.12777 4.59233...
# 3   POLYGON ((-74.06621 4.60317, -74.06620 4.60317...
# 4   POLYGON ((-74.05725 4.68684, -74.06249 4.65594...
# 5   POLYGON ((-74.09372 4.66607, -74.09332 4.66574...
# 6   POLYGON ((-74.11830 4.63741, -74.11504 4.64053...
# 7   POLYGON ((-74.07283 4.61542, -74.07311 4.61480...
# 8   POLYGON ((-74.20584 4.26966, -74.20584 4.26966...
# 9   POLYGON ((-74.01116 4.66459, -74.01117 4.66460...
# 10  POLYGON ((-74.01116 4.66459, -74.01154 4.66461...
# 11  POLYGON ((-73.99446 4.61425, -73.99457 4.61414...
# 12  POLYGON ((-74.02900 4.55830, -74.02930 4.55821...
# 13  POLYGON ((-74.05597 4.50832, -74.05611 4.50822...
# 14  POLYGON ((-74.21092 4.38691, -74.21114 4.38750...
# 15  POLYGON ((-74.18567 4.64705, -74.18480 4.64497...
# 16  POLYGON ((-74.18567 4.64705, -74.18527 4.64699...
# 17  POLYGON ((-74.15857 4.66274, -74.15848 4.66279...
# 18  POLYGON ((-74.15547 4.71798, -74.15547 4.71798...
# 19  POLYGON ((-74.03450 4.82547, -74.03478 4.82418...

# %%
MapaLocalidades.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Carga base TM

# %%
df_TM = pd.read_excel(file_path2)
df_TM
# Out:
#      Shape  objectid  numero_estación   nombre_estación            ubicación  \
# 0    Point         1             2205         Calle 106            Calle 106
# 1    Point         2             2000  Portal del Norte            Calle 173
# 2    Point         3             7108     AV. El Dorado          Kr 30 Av 28
# 3    Point         4             2204       Pepe Sierra            Calle 116
# 4    Point         5             2103           Mazurén            Calle 152
# ..     ...       ...              ...               ...                  ...
# 144  Point       145            12000     Puente Aranda  calle 13 carrera 47
# 145  Point       146            10006     San Victorino         Kra 10- Cl12
# 146  Point       147            10003     Ciudad Jardín     Kra 10- Cl12 sur
# 147  Point       148            10004         Policarpa      Kra 10- Cl3 sur
# 148  Point       149             7010              Bosa               soacha
#
#     troncal_estación  numero_vagones  numero_accesos  biciestación  capacidad  \
# 0          Autonorte               4               1             0          0
# 1          Autonorte               0               0             0          0
# 2                NQS               1               1             0          0
# 3          Autonorte               2               1             0          0
# 4          Autonorte               5               1             0          0
# ..               ...             ...             ...           ...        ...
# 144         Americas               2               1             0          0
# 145          Cr 7-10               3               2             0          0
# 146          Cr 7-10               2               1             0          0
# 147          Cr 7-10               2               2             0          0
# 148           Soacha               2               1             0          0
#
#      tipo estación  biciparqueadero   latitud   longitud last_edi_1
# 0                4                0  4.692982 -74.056178 2021-09-27
# 1                1                0  4.754621 -74.046035 2021-09-27
# 2                4                0  4.630663 -74.079866 2021-09-27
# 3                4                0  4.698125 -74.055298 2021-09-27
# 4                4                0  4.734585 -74.049218 2021-09-27
# ..             ...              ...       ...        ...        ...
# 144              4                0  4.625669 -74.104640 2021-09-27
# 145              4                0  4.601018 -74.077406 2021-09-27
# 146              4                0  4.581532 -74.090338 2021-09-27
# 147              4                0  4.586257 -74.086921 2021-09-27
# 148              4                0  4.596879 -74.181225 2021-09-27
#
# [149 rows x 15 columns]

# %%
df_TM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Shape             149 non-null    object
#  1   objectid          149 non-null    int64
#  2   numero_estación   149 non-null    int64
#  3   nombre_estación   149 non-null    object
#  4   ubicación         149 non-null    object
#  5   troncal_estación  149 non-null    object
#  6   numero_vagones    149 non-null    int64
#  7   numero_accesos    149 non-null    int64
#  8   biciestación      149 non-null    int64
#  9   capacidad         149 non-null    int64
#  10  tipo estación     149 non-null    int64
#  11  biciparqueadero   149 non-null    int64
#  12  latitud           149 non-null    float64
#  13  longitud          149 non-null    float64
#  14  last_edi_1        149 non-null    datetime64[ns]
#  15  geometry          149 non-null    geometry
# dtypes: datetime64[ns](1), float64(2), geometry(1), int64(8), object(4)
# memory usage: 18.8+ KB

# %%
gdf = gpd.GeoDataFrame(df_TM, geometry=gpd.points_from_xy(df_TM.longitud, df_TM.latitud))
gdf
# Out:
#      Shape  objectid  numero_estación   nombre_estación            ubicación  \
# 0    Point         1             2205         Calle 106            Calle 106
# 1    Point         2             2000  Portal del Norte            Calle 173
# 2    Point         3             7108     AV. El Dorado          Kr 30 Av 28
# 3    Point         4             2204       Pepe Sierra            Calle 116
# 4    Point         5             2103           Mazurén            Calle 152
# ..     ...       ...              ...               ...                  ...
# 144  Point       145            12000     Puente Aranda  calle 13 carrera 47
# 145  Point       146            10006     San Victorino         Kra 10- Cl12
# 146  Point       147            10003     Ciudad Jardín     Kra 10- Cl12 sur
# 147  Point       148            10004         Policarpa      Kra 10- Cl3 sur
# 148  Point       149             7010              Bosa               soacha
#
#     troncal_estación  numero_vagones  numero_accesos  biciestación  capacidad  \
# 0          Autonorte               4               1             0          0
# 1          Autonorte               0               0             0          0
# 2                NQS               1               1             0          0
# 3          Autonorte               2               1             0          0
# 4          Autonorte               5               1             0          0
# ..               ...             ...             ...           ...        ...
# 144         Americas               2               1             0          0
# 145          Cr 7-10               3               2             0          0
# 146          Cr 7-10               2               1             0          0
# 147          Cr 7-10               2               2             0          0
# 148           Soacha               2               1             0          0
#
#      tipo estación  biciparqueadero   latitud   longitud last_edi_1  \
# 0                4                0  4.692982 -74.056178 2021-09-27
# 1                1                0  4.754621 -74.046035 2021-09-27
# 2                4                0  4.630663 -74.079866 2021-09-27
# 3                4                0  4.698125 -74.055298 2021-09-27
# 4                4                0  4.734585 -74.049218 2021-09-27
# ..             ...              ...       ...        ...        ...
# 144              4                0  4.625669 -74.104640 2021-09-27
# 145              4                0  4.601018 -74.077406 2021-09-27
# 146              4                0  4.581532 -74.090338 2021-09-27
# 147              4                0  4.586257 -74.086921 2021-09-27
# 148              4                0  4.596879 -74.181225 2021-09-27
#
#                       geometry
# 0    POINT (-74.05618 4.69298)
# 1    POINT (-74.04604 4.75462)
# 2    POINT (-74.07987 4.63066)
# 3    POINT (-74.05530 4.69813)
# 4    POINT (-74.04922 4.73459)
# ..                         ...
# 144  POINT (-74.10464 4.62567)
# 145  POINT (-74.07741 4.60102)
# 146  POINT (-74.09034 4.58153)
# 147  POINT (-74.08692 4.58626)
# 148  POINT (-74.18122 4.59688)
#
# [149 rows x 16 columns]

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Shape             149 non-null    object
#  1   objectid          149 non-null    int64
#  2   numero_estación   149 non-null    int64
#  3   nombre_estación   149 non-null    object
#  4   ubicación         149 non-null    object
#  5   troncal_estación  149 non-null    object
#  6   numero_vagones    149 non-null    int64
#  7   numero_accesos    149 non-null    int64
#  8   biciestación      149 non-null    int64
#  9   capacidad         149 non-null    int64
#  10  tipo estación     149 non-null    int64
#  11  biciparqueadero   149 non-null    int64
#  12  latitud           149 non-null    float64
#  13  longitud          149 non-null    float64
#  14  last_edi_1        149 non-null    datetime64[ns]
#  15  geometry          149 non-null    geometry
# dtypes: datetime64[ns](1), float64(2), geometry(1), int64(8), object(4)
# memory usage: 18.8+ KB

# %%
base1 = gpd.sjoin(gdf,MapaLocalidades[['geometry','Nombre_Localidad','geometry2']], how='left',op='within')
base1
# Out:
# D:\JUAN CAMILO\Anaconda\envs\geo_env\lib\site-packages\IPython\core\interactiveshell.py:3472: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\JUAN CAMILO\AppData\Local\Temp\ipykernel_10444\3833747746.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4686
#
#   base1 = gpd.sjoin(gdf,MapaLocalidades[['geometry','Nombre_Localidad','geometry2']], how='left',op='within')
#      Shape  objectid  numero_estación   nombre_estación            ubicación  \
# 0    Point         1             2205         Calle 106            Calle 106
# 1    Point         2             2000  Portal del Norte            Calle 173
# 2    Point         3             7108     AV. El Dorado          Kr 30 Av 28
# 3    Point         4             2204       Pepe Sierra            Calle 116
# 4    Point         5             2103           Mazurén            Calle 152
# ..     ...       ...              ...               ...                  ...
# 144  Point       145            12000     Puente Aranda  calle 13 carrera 47
# 145  Point       146            10006     San Victorino         Kra 10- Cl12
# 146  Point       147            10003     Ciudad Jardín     Kra 10- Cl12 sur
# 147  Point       148            10004         Policarpa      Kra 10- Cl3 sur
# 148  Point       149             7010              Bosa               soacha
#
#     troncal_estación  numero_vagones  numero_accesos  biciestación  capacidad  \
# 0          Autonorte               4               1             0          0
# 1          Autonorte               0               0             0          0
# 2                NQS               1               1             0          0
# 3          Autonorte               2               1             0          0
# 4          Autonorte               5               1             0          0
# ..               ...             ...             ...           ...        ...
# 144         Americas               2               1             0          0
# 145          Cr 7-10               3               2             0          0
# 146          Cr 7-10               2               1             0          0
# 147          Cr 7-10               2               2             0          0
# 148           Soacha               2               1             0          0
#
#      tipo estación  biciparqueadero   latitud   longitud last_edi_1  \
# 0                4                0  4.692982 -74.056178 2021-09-27
# 1                1                0  4.754621 -74.046035 2021-09-27
# 2                4                0  4.630663 -74.079866 2021-09-27
# 3                4                0  4.698125 -74.055298 2021-09-27
# 4                4                0  4.734585 -74.049218 2021-09-27
# ..             ...              ...       ...        ...        ...
# 144              4                0  4.625669 -74.104640 2021-09-27
# 145              4                0  4.601018 -74.077406 2021-09-27
# 146              4                0  4.581532 -74.090338 2021-09-27
# 147              4                0  4.586257 -74.086921 2021-09-27
# 148              4                0  4.596879 -74.181225 2021-09-27
#
#                       geometry  index_right Nombre_Localidad  \
# 0    POINT (-74.05618 4.69298)          9.0          Usaquén
# 1    POINT (-74.04604 4.75462)          9.0          Usaquén
# 2    POINT (-74.07987 4.63066)          5.0      Teusaquillo
# 3    POINT (-74.05530 4.69813)          9.0          Usaquén
# 4    POINT (-74.04922 4.73459)          9.0          Usaquén
# ..                         ...          ...              ...
# 144  POINT (-74.10464 4.62567)          6.0    Puente Aranda
# 145  POINT (-74.07741 4.60102)          3.0    La Candelaria
# 146  POINT (-74.09034 4.58153)          0.0   Antonio Nariño
# 147  POINT (-74.08692 4.58626)         12.0    San Cristobal
# 148  POINT (-74.18122 4.59688)         14.0   Ciudad Bolivar
#
#                                              geometry2
# 0    POLYGON ((-74.01116 4.66459, -74.01117 4.66460...
# 1    POLYGON ((-74.01116 4.66459, -74.01117 4.66460...
# 2    POLYGON ((-74.09372 4.66607, -74.09332 4.66574...
# 3    POLYGON ((-74.01116 4.66459, -74.01117 4.66460...
# 4    POLYGON ((-74.01116 4.66459, -74.01117 4.66460...
# ..                                                 ...
# 144  POLYGON ((-74.11830 4.63741, -74.11504 4.64053...
# 145  POLYGON ((-74.06621 4.60317, -74.06620 4.60317...
# 146  POLYGON ((-74.13075 4.59335, -74.12917 4.59327...
# 147  POLYGON ((-74.02900 4.55830, -74.02930 4.55821...
# 148  POLYGON ((-74.21092 4.38691, -74.21114 4.38750...
#
# [149 rows x 19 columns]

# %%
base1.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 149 entries, 0 to 148
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Shape             149 non-null    object
#  1   objectid          149 non-null    int64
#  2   numero_estación   149 non-null    int64
#  3   nombre_estación   149 non-null    object
#  4   ubicación         149 non-null    object
#  5   troncal_estación  149 non-null    object
#  6   numero_vagones    149 non-null    int64
#  7   numero_accesos    149 non-null    int64
#  8   biciestación      149 non-null    int64
#  9   capacidad         149 non-null    int64
#  10  tipo estación     149 non-null    int64
#  11  biciparqueadero   149 non-null    int64
#  12  latitud           149 non-null    float64
#  13  longitud          149 non-null    float64
#  14  last_edi_1        149 non-null    datetime64[ns]
#  15  geometry          149 non-null    geometry
#  16  index_right       145 non-null    float64
#  17  Nombre_Localidad  145 non-null    object
#  18  geometry2         145 non-null    geometry
# dtypes: datetime64[ns](1), float64(3), geometry(2), int64(8), object(5)
# memory usage: 23.3+ KB

# %%
base1.geometry2.plot()
# Out:
# <AxesSubplot:>

# %%
base1.geometry.plot()
# Out:
# <AxesSubplot:>
