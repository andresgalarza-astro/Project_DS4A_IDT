# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.graph_objs as go 
import plotly.express as px
from google.colab import drive

# %%
# Connect Drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Read Datasets
df=pd.read_csv('gdrive/My Drive/DS4A/Project/Datasets/4. Base de datos de establecimientos AirBnb en Bogotá 2020-.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4,14,29,41,42,50,51) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Property ID                                    Listing Title  \
# 0  ab-44018885                           Hermosa casa, El nogal
# 1  ab-44019196                     CÓMODO, CENTRAL Y TRANQUILO.
# 2  ab-44020565  Habitación Grande baño privado y terraza. 3piso
# 3  ab-44030858                            Hotel A&M florida 401
# 4  ab-44033318   Habitacion en bogota cerca a el aeropuerto 201
#
#       Property Type     Listing Type Created Date Last Scraped Date   Country  \
# 0  Residential home  Entire home/apt   2020-10-22        2022-02-14  Colombia
# 1        Guesthouse  Entire home/apt   2020-10-09        2022-02-15  Colombia
# 2       Guest suite     Private room   2020-10-25        2022-02-14  Colombia
# 3         Apartment  Entire home/apt   2020-07-17        2021-01-30  Colombia
# 4             House     Private room   2020-10-20        2020-11-04  Colombia
#
#    Latitude  Longitude  State    City  Zipcode    Neighborhood  \
# 0   4.66309  -74.05459    NaN  Bogotá      NaN       Chapinero
# 1   4.63608  -74.07005    NaN  Bogotá      NaN  Teusaquillo
# 2   4.75203  -74.05508    NaN  Bogotá      NaN  Suba
# 3   4.70717  -74.12482    NaN  Bogotá      NaN  Engativa
# 4   4.67015  -74.10249    NaN  Bogotá      NaN  Engativa
#
#    Metropolitan Statistical Area Currency Native  Average Daily Rate (USD)  \
# 0                            NaN             COP                     65.14
# 1                            NaN             COP                     14.00
# 2                            NaN             COP                       NaN
# 3                            NaN             COP                       NaN
# 4                            NaN             COP                       NaN
#
#    Average Daily Rate (Native)  Annual Revenue LTM (USD)  \
# 0                     250000.0                     912.0
# 1                      55000.0                     784.0
# 2                          NaN                       0.0
# 3                          NaN                       0.0
# 4                          NaN                       0.0
#
#    Annual Revenue LTM (Native)  Occupancy Rate LTM  Number of Bookings LTM  \
# 0                    3500000.0               0.070                     8.0
# 1                    3080000.0               0.371                     7.0
# 2                          0.0                 NaN                     0.0
# 3                          0.0                 NaN                     0.0
# 4                          0.0                 NaN                     0.0
#
#    Count Reservation Days LTM  Count Available Days LTM  \
# 0                        14.0                     186.0
# 1                        56.0                      95.0
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#    Count Blocked Days LTM  Bedrooms  Bathrooms  Max Guests  \
# 0                    14.0       4.0        3.0         5.0
# 1                     3.0       1.0        1.0         2.0
# 2                     NaN       1.0        1.0         1.0
# 3                     NaN       3.0        1.0         4.0
# 4                     NaN       1.0        1.0         4.0
#
#   Calendar Last Updated  Response Rate Airbnb Superhost  \
# 0                   NaN            0.0            False
# 1                   NaN           78.0            False
# 2                   NaN            0.0            False
# 3                   NaN           60.0            False
# 4                   NaN          100.0            False
#
#   HomeAway Premier Partner Cancellation Policy  Security Deposit (USD)  \
# 0                      NaN            flexible                     NaN
# 1                      NaN            flexible                     NaN
# 2                      NaN            flexible                     NaN
# 3                      NaN            flexible                     NaN
# 4                      NaN            flexible                     NaN
#
#    Security Deposit (Native)  Cleaning Fee (USD)  Cleaning Fee (Native)  \
# 0                        NaN                 NaN                    NaN
# 1                        NaN                 NaN                    NaN
# 2                        NaN                 NaN                    NaN
# 3                        NaN                 9.0                    NaN
# 4                        NaN                 5.0                    NaN
#
#    Extra People Fee (USD)  Extra People Fee (Native)  \
# 0                     NaN                        NaN
# 1                     NaN                        NaN
# 2                     NaN                        NaN
# 3                     NaN                        NaN
# 4                     NaN                        NaN
#
#    Published Nightly Rate (USD)  Published Monthly Rate (USD)  \
# 0                          63.0                           NaN
# 1                          14.0                           NaN
# 2                          15.0                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    Published Weekly Rate (USD)      Check-in Time Checkout Time  Minimum Stay  \
# 0                          NaN                NaN           NaN           1.0
# 1                          NaN  9:00 AM - 4:00 PM       4:00 PM           3.0
# 2                          NaN           Flexible       1:00 AM           1.0
# 3                          NaN     After 10:00 AM       6:00 PM           1.0
# 4                          NaN      After 3:00 PM           NaN           1.0
#
#    Number of Reviews  Number of Photos  Instantbook Enabled  Overall Rating  \
# 0                0.0              11.0                False             NaN
# 1                5.0               5.0                 True             5.0
# 2                0.0               8.0                False             NaN
# 3                2.0              17.0                False             4.5
# 4                0.0              17.0                 True             NaN
#
#    Airbnb Property ID  Airbnb Host ID                     Airbnb Listing URL  \
# 0          44018885.0     351991717.0  https://www.airbnb.com/rooms/44018885
# 1          44019196.0     352772452.0  https://www.airbnb.com/rooms/44019196
# 2          44020565.0      30434345.0  https://www.airbnb.com/rooms/44020565
# 3          44030858.0     338182528.0  https://www.airbnb.com/rooms/44030858
# 4          44033318.0     264501662.0  https://www.airbnb.com/rooms/44033318
#
#                        Airbnb Listing Main Image URL HomeAway Property ID  \
# 0  https://a0.muscache.com/im/pictures/496e7391-2...                  NaN
# 1  https://a0.muscache.com/im/pictures/b3495a0b-6...                  NaN
# 2  https://a0.muscache.com/im/pictures/25525e57-8...                  NaN
# 3  https://a0.muscache.com/im/pictures/6f60d777-5...                  NaN
# 4  https://a0.muscache.com/im/pictures/9c8596b9-d...                  NaN
#
#   HomeAway Property Manager HomeAway Listing URL  \
# 0                       NaN                  NaN
# 1                       NaN                  NaN
# 2                       NaN                  NaN
# 3                       NaN                  NaN
# 4                       NaN                  NaN
#
#   HomeAway Listing Main Image URL
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49953 entries, 0 to 49952
# Data columns (total 56 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Property ID                      49953 non-null  object
#  1   Listing Title                    49924 non-null  object
#  2   Property Type                    49917 non-null  object
#  3   Listing Type                     49926 non-null  object
#  4   Created Date                     48135 non-null  object
#  5   Last Scraped Date                49953 non-null  object
#  6   Country                          49953 non-null  object
#  7   Latitude                         49953 non-null  float64
#  8   Longitude                        49953 non-null  float64
#  9   State                            0 non-null      float64
#  10  City                             49953 non-null  object
#  11  Zipcode                          0 non-null      float64
#  12  Neighborhood                     49621 non-null  object
#  13  Metropolitan Statistical Area    0 non-null      float64
#  14  Currency Native                  47780 non-null  object
#  15  Average Daily Rate (USD)         12863 non-null  float64
#  16  Average Daily Rate (Native)      12536 non-null  float64
#  17  Annual Revenue LTM (USD)         49799 non-null  float64
#  18  Annual Revenue LTM (Native)      47986 non-null  float64
#  19  Occupancy Rate LTM               12865 non-null  float64
#  20  Number of Bookings LTM           49799 non-null  float64
#  21  Count Reservation Days LTM       12865 non-null  float64
#  22  Count Available Days LTM         12865 non-null  float64
#  23  Count Blocked Days LTM           12865 non-null  float64
#  24  Bedrooms                         49912 non-null  float64
#  25  Bathrooms                        49837 non-null  float64
#  26  Max Guests                       49882 non-null  float64
#  27  Calendar Last Updated            34394 non-null  object
#  28  Response Rate                    41984 non-null  float64
#  29  Airbnb Superhost                 47780 non-null  object
#  30  HomeAway Premier Partner         1757 non-null   object
#  31  Cancellation Policy              49550 non-null  object
#  32  Security Deposit (USD)           5400 non-null   float64
#  33  Security Deposit (Native)        5116 non-null   float64
#  34  Cleaning Fee (USD)               19463 non-null  float64
#  35  Cleaning Fee (Native)            12002 non-null  float64
#  36  Extra People Fee (USD)           9712 non-null   float64
#  37  Extra People Fee (Native)        8947 non-null   float64
#  38  Published Nightly Rate (USD)     48106 non-null  float64
#  39  Published Monthly Rate (USD)     28926 non-null  float64
#  40  Published Weekly Rate (USD)      28955 non-null  float64
#  41  Check-in Time                    40772 non-null  object
#  42  Checkout Time                    24968 non-null  object
#  43  Minimum Stay                     49642 non-null  float64
#  44  Number of Reviews                49723 non-null  float64
#  45  Number of Photos                 49678 non-null  float64
#  46  Instantbook Enabled              49953 non-null  bool
#  47  Overall Rating                   21633 non-null  float64
#  48  Airbnb Property ID               48135 non-null  float64
#  49  Airbnb Host ID                   48100 non-null  float64
#  50  Airbnb Listing URL               48135 non-null  object
#  51  Airbnb Listing Main Image URL    47938 non-null  object
#  52  HomeAway Property ID             2321 non-null   object
#  53  HomeAway Property Manager        672 non-null    object
#  54  HomeAway Listing URL             2321 non-null   object
#  55  HomeAway Listing Main Image URL  2320 non-null   object
# dtypes: bool(1), float64(33), object(22)
# memory usage: 21.0+ MB

# %%
# Drop records with NA values
#df.dropna(axis = 1, inplace = True)

# %%
property_df = pd.DataFrame(df['Property Type'].value_counts()).reset_index().sort_values('Property Type', ascending = False).head(10).sort_values('Property Type')
ax = px.bar(property_df, x='Property Type', y='index', labels = {'Property Type':'# of Establishments', 
                                                              'index':'Property Type'}, title = 'Airbnb Establishments by Property Type')
ax.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="35c01f00-5fef-4f79-a2b7-1c243f4a1540" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35c01f00-5fef-4f79-a2b7-1c243f4a1540")) {                    Plotly.newPlot(                        "35c01f00-5fef-4f79-a2b7-1c243f4a1540",                        [{"alignmentgroup":"True","hovertemplate":"# of Establishments=%{x}<br>Property Type=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[533,773,1433,1524,1611,2072,2766,2785,13420,17665],"xaxis":"x","y":["Entire apartment","Bed and breakfast","Serviced apartment","Loft","Condominium","Condominium (condo)","Residential home","House","Rental unit","Apartment"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type": ...

# %%
property_df = pd.DataFrame(df['Neighborhood'].value_counts()).reset_index().sort_values('Neighborhood', ascending = False).head(10).sort_values('Neighborhood')
ax = px.bar(property_df, x='Neighborhood', y='index', labels = {'Neighborhood':'# of Establishments', 
                                                              'index':'Neighborhood'}, title = 'Airbnb Establishments by Neighborhood')
ax.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3449c52b-2b4a-4dbd-b25f-90f8c06eeab5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3449c52b-2b4a-4dbd-b25f-90f8c06eeab5")) {                    Plotly.newPlot(                        "3449c52b-2b4a-4dbd-b25f-90f8c06eeab5",                        [{"alignmentgroup":"True","hovertemplate":"# of Establishments=%{x}<br>Neighborhood=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[559,1499,2244,2361,2888,4364,6213,6844,9466,11850],"xaxis":"x","y":["Puente Aranda ","Kennedy       ","Barrios Unidos","Fontibon      ","Engativa      ","Santa Fe      ","Suba          ","Teusaquillo   ","Usaquen","Chapinero"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type" ...

# %%
df[['Average Daily Rate (USD)', 'Average Daily Rate (Native)', 'Published Nightly Rate (USD)', 'Published Monthly Rate (USD)', 'Published Weekly Rate (USD)']].describe()
# Out:
#        Average Daily Rate (USD)  Average Daily Rate (Native)  \
# count              12863.000000                 1.253600e+04
# mean                  37.345963                 8.554251e+04
# std                   52.514009                 1.015023e+05
# min                    5.000000                 9.000000e+00
# 25%                   17.455000                 1.409725e+02
# 50%                   26.730000                 6.954545e+04
# 75%                   42.875000                 1.190000e+05
# max                 3309.330000                 2.500000e+06
#
#        Published Nightly Rate (USD)  Published Monthly Rate (USD)  \
# count                  48106.000000                  2.892600e+04
# mean                      67.111753                  2.894697e+03
# std                     1415.949611                  7.096300e+04
# min                        0.000000                  0.000000e+00
# 25%                       14.000000                  4.130000e+02
# 50%                       24.000000                  7.000000e+02
# 75%                       44.000000                  1.244750e+03
# max                   236900.000000                  6.633200e+06
#
#        Published Weekly Rate (USD)
# count                 2.895500e+04
# mean                  7.526834e+02
# std                   1.901260e+04
# min                   0.000000e+00
# 25%                   1.050000e+02
# 50%                   1.760000e+02
# 75%                   3.180000e+02
# max                   1.658300e+06

# %%
df['Property Type'].values_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-927a19ee2a49> in <module>()
# ----> 1 df['Property Type'].values_counts()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'values_counts'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49953 entries, 0 to 49952
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Property ID          49953 non-null  object
#  1   Last Scraped Date    49953 non-null  object
#  2   Country              49953 non-null  object
#  3   Latitude             49953 non-null  float64
#  4   Longitude            49953 non-null  float64
#  5   City                 49953 non-null  object
#  6   Instantbook Enabled  49953 non-null  bool
# dtypes: bool(1), float64(2), object(4)
# memory usage: 2.3+ MB

# %%
df.describe().drop(columns=['Latitude', 'Longitude', 'State', 'Zipcode', 'Metropolitan Statistical Area'])
# Out:
#        Average Daily Rate (USD)  Average Daily Rate (Native)  \
# count              12863.000000                 1.253600e+04
# mean                  37.345963                 8.554251e+04
# std                   52.514009                 1.015023e+05
# min                    5.000000                 9.000000e+00
# 25%                   17.455000                 1.409725e+02
# 50%                   26.730000                 6.954545e+04
# 75%                   42.875000                 1.190000e+05
# max                 3309.330000                 2.500000e+06
#
#        Annual Revenue LTM (USD)  Annual Revenue LTM (Native)  \
# count              49799.000000                 4.798600e+04
# mean                 466.477500                 9.552860e+05
# std                 2189.277295                 4.092747e+06
# min                    0.000000                 0.000000e+00
# 25%                    0.000000                 0.000000e+00
# 50%                    0.000000                 0.000000e+00
# 75%                   22.000000                 1.680000e+02
# max               123480.000000                 2.735986e+08
#
#        Occupancy Rate LTM  Number of Bookings LTM  Count Reservation Days LTM  \
# count        12865.000000            49799.000000                12865.000000
# mean             0.380226                3.646298                   45.442752
# std              0.269744               11.117845                   54.586608
# min              0.032000                0.000000                    1.000000
# 25%              0.139000                0.000000                    8.000000
# 50%              0.333000                0.000000                   25.000000
# 75%              0.581000                1.000000                   62.000000
# max              1.000000              182.000000                  343.000000
#
#        Count Available Days LTM  Count Blocked Days LTM      Bedrooms  \
# count              12865.000000            12865.000000  49912.000000
# mean                  64.473921               24.034357      1.458787
# std                   56.017969               35.987824      1.600119
# min                    0.000000                0.000000      0.000000
# 25%                   26.000000                0.000000      1.000000
# 50%                   47.000000                5.000000      1.000000
# 75%                   89.000000               34.000000      2.000000
# max                  333.000000              252.000000     50.000000
#
#           Bathrooms    Max Guests  Response Rate  Security Deposit (USD)  \
# count  49837.000000  49882.000000   41984.000000             5400.000000
# mean       1.480145      2.889499      71.558808              226.658704
# std        1.273271      2.289247      40.848764              328.079603
# min        0.000000      0.000000       0.000000               50.000000
# 25%        1.000000      2.000000      44.000000              101.000000
# 50%        1.000000      2.000000     100.000000              150.000000
# 75%        2.000000      4.000000     100.000000              246.250000
# max       50.000000    100.000000     100.000000             5253.000000
#
#        Security Deposit (Native)  Cleaning Fee (USD)  Cleaning Fee (Native)  \
# count               5.116000e+03        19463.000000           1.200200e+04
# mean                2.229585e+05           18.735395           1.417870e+04
# std                 7.538482e+05          161.361087           2.775777e+04
# min                 5.200000e+01            1.000000           1.000000e+00
# 25%                 1.060000e+02            8.000000           1.500000e+01
# 50%                 2.500000e+02           13.000000           2.700000e+01
# 75%                 3.000000e+05           20.000000           2.200000e+04
# max                 1.593174e+07        19000.000000           1.000001e+06
#
#        Extra People Fee (USD)  Extra People Fee (Native)  \
# count             9712.000000                8947.000000
# mean                12.815898               17208.822622
# std                 12.789258               29720.735568
# min                  1.000000                   1.000000
# 25%                  7.000000                  10.000000
# 50%                 10.000000                  40.000000
# 75%                 15.000000               30000.000000
# max                300.000000              850000.000000
#
#        Published Nightly Rate (USD)  Published Monthly Rate (USD)  \
# count                  48106.000000                  2.892600e+04
# mean                      67.111753                  2.894697e+03
# std                     1415.949611                  7.096300e+04
# min                        0.000000                  0.000000e+00
# 25%                       14.000000                  4.130000e+02
# 50%                       24.000000                  7.000000e+02
# 75%                       44.000000                  1.244750e+03
# max                   236900.000000                  6.633200e+06
#
#        Published Weekly Rate (USD)  Minimum Stay  Number of Reviews  \
# count                 2.895500e+04   49642.00000       49723.000000
# mean                  7.526834e+02       5.44410           5.768799
# std                   1.901260e+04      19.88048          20.229792
# min                   0.000000e+00       0.00000           0.000000
# 25%                   1.050000e+02       1.00000           0.000000
# 50%                   1.760000e+02       1.00000           0.000000
# 75%                   3.180000e+02       3.00000           3.000000
# max                   1.658300e+06     569.00000        1470.000000
#
#        Number of Photos  Overall Rating  Airbnb Property ID  Airbnb Host ID
# count      49678.000000    21633.000000        4.813500e+04    4.810000e+04
# mean          14.313096        5.820718        1.922367e+15    1.369152e+08
# std           14.983132       10.188055        3.229924e+16    1.087437e+08
# min            0.000000        1.000000        6.627000e+03    7.061000e+03
# 25%            6.000000        4.500000        1.755894e+07    4.108184e+07
# 50%           10.000000        4.800000        2.783655e+07    1.165942e+08
# 75%           17.000000        5.000000        3.967151e+07    2.135242e+08
# max          199.000000      100.000000        5.593184e+17    4.444750e+08

# %%
# Revisar valores de todas las columnas
for col in df.columns:
  print(df[col].value_counts())
# Out:
# ab-44018885    1
# ab-38776031    1
# ab-38753515    1
# ab-38753975    1
# ab-38754143    1
#               ..
# ab-31917517    1
# ab-31918510    1
# ab-31919799    1
# ab-31919841    1
# ha-967007      1
# Name: Property ID, Length: 49953, dtype: int64
# Habitación privada                                    74
# Habitación                                            55
# Bogotá Departamento                                   44
# Apartamento                                           35
# Habitación con baño privado                           31
#                                                       ..
# Best Place in Bogotá. ¡¡Great for big groups!! :D      1
# Affordable Cozy Room for 2!! Habitación Económica!     1
# MODERNO APARTAMENTO EN LO MEJOR! ZONA G!               1
# Hospedaje seguro                                       1
# Cozy Townhouse in Bogota                               1
# Name: Listing Title, Length: 46192, dtype: int64
# Apartment                          17665
# Rental unit                        13420
# House                               2785
# Residential home                    2766
# Condominium (condo)                 2072
#                                    ...
# Private room in casa particular        1
# Entire floor                           1
# Private room in floor                  1
# Cave                                   1
# studio                                 1
# Name: Property Type, Length: 143, dtype: int64
# Entire home/apt    24958
# Private room       23561
# Shared room         1169
# Hotel room           238
# Name: Listing Type, dtype: int64
# 2019-12-13    821
# 2019-02-25    489
# 2020-10-21    341
# 2020-10-22    320
# 2018-06-29    240
#              ...
# 2012-10-14      1
# 2012-10-17      1
# 2020-04-15      1
# 2012-10-18      1
# 2013-03-09      1
# Name: Created Date, Length: 2956, dtype: int64
# 2022-02-14    16362
# 2022-02-15     1529
# 2020-01-29     1318
# 2022-02-13     1025
# 2019-10-15      267
#               ...
# 2016-12-04        1
# 2020-02-12        1
# 2016-07-17        1
# 2015-05-06        1
# 2017-02-10        1
# Name: Last Scraped Date, Length: 1969, dtype: int64
# Colombia    49953
# Name: Country, dtype: int64
# 4.680000    64
# 4.648000    61
# 4.640000    58
# 4.642000    48
# 4.643000    48
#             ..
# 4.710709     1
# 4.640203     1
# 4.647120     1
# 4.645841     1
# 4.752012     1
# Name: Latitude, Length: 28448, dtype: int64
# -74.072000    106
# -74.070000    100
# -74.062000     98
# -74.057000     92
# -74.068000     89
#              ...
# -74.073394      1
# -74.047453      1
# -74.071022      1
# -74.100420      1
# -74.085558      1
# Name: Longitude, Length: 24860, dtype: int64
# Series([], Name: State, dtype: int64)
# Bogotá    49953
# Name: City, dtype: int64
# Series([], Name: Zipcode, dtype: int64)
# Chapinero         11850
# Usaquen            9466
# Teusaquillo        6844
# Suba               6213
# Santa Fe           4364
# Engativa           2888
# Fontibon           2361
# Barrios Unidos     2244
# Kennedy            1499
# Puente Aranda       559
# Los Martires        492
# San Cristobal       237
# Antonio Narino      171
# Rafael Uribe        166
# Bosa                162
# Tunjuelito          105
# Name: Neighborhood, dtype: int64
# Series([], Name: Metropolitan Statistical Area, dtype: int64)
# COP    32368
# USD    14450
# EUR      803
# GBP       69
# AUD       16
# CAD       14
# CLP       11
# ARS        7
# SEK        6
# MXN        5
# CRC        4
# CZK        3
# BRL        3
# CNY        3
# PEN        3
# THB        2
# DKK        2
# CHF        2
# AED        1
# PHP        1
# TWD        1
# VND        1
# SGD        1
# HUF        1
# NZD        1
# NOK        1
# HKD        1
# Name: Currency Native, dtype: int64
# 10.00     482
# 11.00     137
# 12.00     133
# 13.00     123
# 20.00     117
#          ...
# 117.04      1
# 52.14       1
# 136.00      1
# 30.07       1
# 116.50      1
# Name: Average Daily Rate (USD), Length: 4789, dtype: int64
# 40000.00     142
# 50000.00     136
# 60000.00     120
# 45000.00      91
# 100000.00     81
#             ...
# 139319.97      1
# 169617.20      1
# 44162.00       1
# 56930.97       1
# 151233.10      1
# Name: Average Daily Rate (Native), Length: 9355, dtype: int64
# 0.0        36936
# 10.0          78
# 20.0          72
# 60.0          66
# 30.0          64
#            ...
# 19176.0        1
# 4683.0         1
# 1646.0         1
# 3754.0         1
# 1537.0         1
# Name: Annual Revenue LTM (USD), Length: 4242, dtype: int64
# 0.0           35450
# 120000.0         36
# 600000.0         35
# 400000.0         31
# 40000.0          31
#               ...
# 1926373.0         1
# 511845.0          1
# 3500334.0         1
# 538816.0          1
# 18299206.0        1
# Name: Annual Revenue LTM (Native), Length: 9653, dtype: int64
# 0.032    412
# 1.000    264
# 0.065    224
# 0.194    195
# 0.033    188
#         ...
# 0.854      1
# 0.546      1
# 0.952      1
# 0.166      1
# 0.881      1
# Name: Occupancy Rate LTM, Length: 944, dtype: int64
# 0.0      35883
# 1.0       2455
# 2.0       1408
# 3.0       1051
# 4.0        853
#          ...
# 176.0        1
# 141.0        1
# 118.0        1
# 103.0        1
# 142.0        1
# Name: Number of Bookings LTM, Length: 134, dtype: int64
# 1.0      729
# 2.0      491
# 3.0      483
# 6.0      442
# 5.0      371
#         ...
# 274.0      1
# 291.0      1
# 263.0      1
# 334.0      1
# 276.0      1
# Name: Count Reservation Days LTM, Length: 308, dtype: int64
# 30.0     464
# 29.0     388
# 27.0     343
# 25.0     309
# 28.0     298
#         ...
# 249.0      1
# 305.0      1
# 273.0      1
# 333.0      1
# 300.0      1
# Name: Count Available Days LTM, Length: 299, dtype: int64
# 0.0      5011
# 1.0       463
# 2.0       345
# 3.0       271
# 4.0       205
#          ...
# 193.0       1
# 202.0       1
# 219.0       1
# 164.0       1
# 198.0       1
# Name: Count Blocked Days LTM, Length: 208, dtype: int64
# 1.0     33769
# 2.0      8320
# 3.0      3819
# 0.0      2461
# 4.0       747
# 5.0       210
# 10.0      136
# 6.0       109
# 7.0        74
# 9.0        38
# 8.0        37
# 12.0       27
# 20.0       26
# 15.0       24
# 13.0       16
# 11.0       14
# 16.0       13
# 14.0        9
# 50.0        6
# 22.0        6
# 18.0        5
# 19.0        4
# 27.0        4
# 28.0        4
# 32.0        4
# 25.0        4
# 30.0        3
# 17.0        3
# 23.0        3
# 35.0        3
# 26.0        2
# 36.0        2
# 40.0        2
# 21.0        2
# 33.0        1
# 34.0        1
# 47.0        1
# 38.0        1
# 29.0        1
# 49.0        1
# Name: Bedrooms, dtype: int64
# 1.0     31691
# 2.0      9004
# 1.5      3847
# 2.5      1641
# 3.0      1500
# 0.0       451
# 3.5       391
# 4.0       387
# 5.0       162
# 4.5       133
# 8.0       111
# 0.5        99
# 6.0        92
# 10.0       53
# 7.0        49
# 5.5        35
# 12.0       32
# 6.5        19
# 9.0        15
# 8.5        15
# 15.0       12
# 11.0       10
# 16.0       10
# 20.0        9
# 17.0        7
# 13.0        7
# 18.0        6
# 10.5        4
# 7.5         4
# 35.0        3
# 22.0        3
# 13.5        3
# 23.0        3
# 32.0        3
# 28.0        3
# 11.5        2
# 29.5        2
# 14.0        2
# 27.0        2
# 9.5         2
# 25.0        2
# 37.0        1
# 50.0        1
# 26.5        1
# 21.0        1
# 42.0        1
# 20.5        1
# 31.0        1
# 19.5        1
# 45.0        1
# 12.5        1
# 25.5        1
# Name: Bathrooms, dtype: int64
# 2.0      20075
# 1.0      10213
# 4.0       7817
# 3.0       5382
# 5.0       2118
# 6.0       2059
# 8.0        569
# 16.0       419
# 7.0        416
# 10.0       286
# 9.0        186
# 12.0       142
# 15.0        75
# 14.0        56
# 11.0        27
# 13.0        24
# 20.0         6
# 0.0          3
# 60.0         2
# 22.0         1
# 24.0         1
# 25.0         1
# 30.0         1
# 100.0        1
# 31.0         1
# 17.0         1
# Name: Max Guests, dtype: int64
# 2019-08-30    505
# 2019-08-29    374
# 2019-08-31    332
# 2019-08-21    272
# 2019-08-28    256
#              ...
# 2014-05-04      1
# 2015-02-22      1
# 2014-06-22      1
# 2015-03-24      1
# 2014-09-01      1
# Name: Calendar Last Updated, Length: 1971, dtype: int64
# 100.0    22786
# 0.0       8894
# 50.0      1359
# 90.0       703
# 80.0       613
#          ...
# 24.0         1
# 23.0         1
# 72.0         1
# 52.0         1
# 15.0         1
# Name: Response Rate, Length: 86, dtype: int64
# False    45275
# True      2505
# Name: Airbnb Superhost, dtype: int64
# False    1757
# Name: HomeAway Premier Partner, dtype: int64
# flexible                                                                                                                       21717
# moderate                                                                                                                        5129
# strict_14_with_grace_period                                                                                                     4625
# Flexible - Free cancellation for 48 hours                                                                                       4080
# Flexible                                                                                                                        3672
# Free cancellation for 48 hours                                                                                                  1660
# Flexible · Free cancellation for 48 hours                                                                                       1414
# Moderate - Free cancellation for 48 hours                                                                                        798
# Flexible · Free cancellation for 48 hours.                                                                                       749
# Moderate                                                                                                                         692
# {"policy": "UNDEFINED", "policyPeriods": [{"limitedTo": 7, "refundPercent": 50}, {"limitedTo": 14, "refundPercent": 100}]}       663
# Flexible policy –  Free cancellation within 48 hours                                                                             595
# Strict                                                                                                                           549
# Strict - Free cancellation for 48 hours                                                                                          476
# strict                                                                                                                           457
# firm                                                                                                                             361
# {"policy": "UNDEFINED", "policyPeriods": []}                                                                                     240
# Moderate · Free cancellation for 48 hours                                                                                        223
# Strict · Free cancellation for 48 hours                                                                                          191
# {"policy": "UNDEFINED", "policyPeriods": [{"limitedTo": 60, "refundPercent": 100}]}                                              181
# {"policy": "UNDEFINED", "policyPeriods": [{"limitedTo": 14, "refundPercent": 50}, {"limitedTo": 30, "refundPercent": 100}]}      118
# [{"limitedTo": 0, "refundPercent": 0}]                                                                                           117
# Moderate · Free cancellation for 48 hours.                                                                                       110
# Moderate policy –  Free cancellation within 48 hours                                                                             109
# {"policy": "UNDEFINED", "policyPeriods": [{"limitedTo": 0, "refundPercent": 0}]}                                                 106
# [{"limitedTo": 7, "refundPercent": 50}, {"limitedTo": 14, "refundPercent": 100}]                                                  90
# [{"limitedTo": 60, "refundPercent": 100}]                                                                                         76
# Strict policy  –  Free cancellation within 48 hours                                                                               64
# {"policy": "UNDEFINED", "policyPeriods": [{"limitedTo": 30, "refundPercent": 50}, {"limitedTo": 60, "refundPercent": 100}]}       58
# Strict · Free cancellation for 48 hours.                                                                                          56
# super_strict_60                                                                                                                   42
# []                                                                                                                                39
# [{"limitedTo": 14, "refundPercent": 50}, {"limitedTo": 30, "refundPercent": 100}]                                                 29
# Super Strict 60 Days                                                                                                              16
# super_strict_30                                                                                                                   12
# better_strict                                                                                                                      8
# Super Strict 30 days                                                                                                               8
# Super Strict 60 days                                                                                                               7
# [{"limitedTo": 30, "refundPercent": 50}, {"limitedTo": 60, "refundPercent": 100}]                                                  5
# firm_30_strict                                                                                                                     3
# Super Strict 30                                                                                                                    2
# Super Strict 60                                                                                                                    2
# Super Strict 30 Days                                                                                                               1
# Name: Cancellation Policy, dtype: int64
# 100.0     751
# 103.0     408
# 200.0     361
# 150.0     234
# 206.0     219
#          ...
# 268.0       1
# 237.0       1
# 949.0       1
# 2143.0      1
# 82.0        1
# Name: Security Deposit (USD), Length: 403, dtype: int64
# 100.0       693
# 103.0       381
# 200.0       324
# 300000.0    301
# 500000.0    276
#            ...
# 5150.0        1
# 284330.0      1
# 265.0         1
# 670.0         1
# 281700.0      1
# Name: Security Deposit (Native), Length: 504, dtype: int64
# 8.0      2034
# 5.0      1888
# 15.0     1726
# 10.0     1666
# 13.0     1449
#          ...
# 79.0        1
# 382.0       1
# 195.0       1
# 190.0       1
# 153.0       1
# Name: Cleaning Fee (USD), Length: 123, dtype: int64
# 15.0       1065
# 10.0       1040
# 20.0        877
# 5.0         668
# 50000.0     642
#            ...
# 140.0         1
# 27230.0       1
# 88019.0       1
# 40402.0       1
# 14307.0       1
# Name: Cleaning Fee (Native), Length: 496, dtype: int64
# 10.0     1800
# 5.0      1520
# 6.0       829
# 15.0      640
# 8.0       615
#          ...
# 275.0       1
# 98.0        1
# 150.0       1
# 120.0       1
# 96.0        1
# Name: Extra People Fee (USD), Length: 86, dtype: int64
# 10.0       1270
# 5.0         729
# 20000.0     660
# 30000.0     595
# 15.0        584
#            ...
# 57303.0       1
# 20023.0       1
# 17551.0       1
# 55.0          1
# 14550.0       1
# Name: Extra People Fee (Native), Length: 518, dtype: int64
# 10.0      5603
# 15.0      2084
# 13.0      1809
# 11.0      1654
# 20.0      1578
#           ...
# 614.0        1
# 700.0        1
# 287.0        1
# 1059.0       1
# 2350.0       1
# Name: Published Nightly Rate (USD), Length: 551, dtype: int64
# 840.0       338
# 560.0       328
# 420.0       322
# 280.0       313
# 700.0       305
#            ...
# 1980.0        1
# 256293.0      1
# 1813.0        1
# 188.0         1
# 3178.0        1
# Name: Published Monthly Rate (USD), Length: 2920, dtype: int64
# 70.0      470
# 72.0      379
# 210.0     372
# 140.0     367
# 105.0     358
#          ...
# 1736.0      1
# 1463.0      1
# 1596.0      1
# 1243.0      1
# 1990.0      1
# Name: Published Weekly Rate (USD), Length: 1337, dtype: int64
# After 3:00 PM                    10020
# Flexible                          9940
# After 3PM                         3772
# Anytime after 3PM                 1442
# After 2:00 PM                     1194
#                                  ...
# 7:00 PM                              1
# 4:00 AM                              1
# After 2:00 AM                        1
# 9:00 PM - 12:00 AM                   1
# 11:00 PM - 1:00 AM (next day)        1
# Name: Check-in Time, Length: 381, dtype: int64
# 11:00 AM               5032
# 12:00 PM               4749
# 12PM (noon)            2269
# 1:00 PM                1876
# 11AM                   1109
# 1PM                    1048
# 3:00 PM                 987
# 10:00 AM                910
# 2:00 PM                 805
# 3PM                     634
# 2PM                     522
# 12AM (midnight)         431
# 12:00 AM                391
# 10AM                    332
# 4:00 PM                 290
# 5:00 PM                 284
# 6:00 PM                 262
# 3:00 AM                 219
# 5PM                     207
# 4PM                     195
# 6PM                     193
# 1:00 AM                 182
# 2:00 AM                 146
# 3AM                     143
# 8:00 PM                 127
# 9:00 AM                 125
# 8PM                     120
# 1AM                     113
# 11:00 PM                105
# 7:00 PM                  88
# 2AM                      85
# 8:00 AM                  82
# 11PM                     79
# 12:00 PM (noon)          78
# 4:00 AM                  73
# 7PM                      73
# 5:00 AM                  67
# 9AM                      67
# 10:00 PM                 66
# 8AM                      57
# 9:00 PM                  54
# 6:00 AM                  49
# 9PM                      42
# 10PM                     41
# 4AM                      40
# 5AM                      36
# 7:00 AM                  31
# 7AM                      27
# 6AM                      24
# 12:00 AM (midnight)       2
# Flexible                  1
# Name: Checkout Time, dtype: int64
# 1.0      27595
# 2.0       7650
# 3.0       4724
# 30.0      1727
# 5.0       1630
#          ...
# 569.0        1
# 58.0         1
# 160.0        1
# 95.0         1
# 46.0         1
# Name: Minimum Stay, Length: 90, dtype: int64
# 0.0      27105
# 1.0       6402
# 2.0       3050
# 3.0       1866
# 4.0       1323
#          ...
# 323.0        1
# 204.0        1
# 332.0        1
# 190.0        1
# 424.0        1
# Name: Number of Reviews, Length: 255, dtype: int64
# 7.0      3305
# 8.0      3264
# 6.0      3148
# 9.0      3029
# 5.0      2806
#          ...
# 151.0       1
# 154.0       1
# 158.0       1
# 134.0       1
# 188.0       1
# Name: Number of Photos, Length: 157, dtype: int64
# True     27919
# False    22034
# Name: Instantbook Enabled, dtype: int64
# 5.0      9372
# 4.8      2873
# 4.5      1612
# 4.7      1522
# 4.0      1388
# 4.9      1057
# 3.0       512
# 4.3       502
# 1.0       437
# 4.2       435
# 4.6       413
# 4.4       251
# 3.5       189
# 2.0       180
# 3.6       156
# 100.0     151
# 80.0      144
# 3.8        97
# 3.4        66
# 3.9        57
# 2.5        52
# 4.1        48
# 60.0       22
# 3.2        18
# 2.6        18
# 2.4        13
# 3.7         9
# 3.1         8
# 1.5         7
# 20.0        7
# 2.8         5
# 3.3         4
# 2.2         3
# 40.0        3
# 1.6         1
# 2.9         1
# Name: Overall Rating, dtype: int64
# 44018885.0    1
# 37396383.0    1
# 37386241.0    1
# 37387602.0    1
# 37388137.0    1
#              ..
# 31386594.0    1
# 31386741.0    1
# 31387101.0    1
# 31388745.0    1
# 23918318.0    1
# Name: Airbnb Property ID, Length: 48135, dtype: int64
# 5052218.0      380
# 296581687.0    315
# 213524223.0    297
# 267819123.0    238
# 48225748.0     196
#               ...
# 13443929.0       1
# 6279302.0        1
# 13418997.0       1
# 632792.0         1
# 179780077.0      1
# Name: Airbnb Host ID, Length: 28896, dtype: int64
# https://www.airbnb.com/rooms/44018885    1
# https://www.airbnb.com/rooms/37396383    1
# https://www.airbnb.com/rooms/37386241    1
# https://www.airbnb.com/rooms/37387602    1
# https://www.airbnb.com/rooms/37388137    1
#                                         ..
# https://www.airbnb.com/rooms/31386594    1
# https://www.airbnb.com/rooms/31386741    1
# https://www.airbnb.com/rooms/31387101    1
# https://www.airbnb.com/rooms/31388745    1
# https://www.airbnb.com/rooms/23918318    1
# Name: Airbnb Listing URL, Length: 48135, dtype: int64
# https://a0.muscache.com/im/pictures/7de34810-5412-41f5-978c-bb100ec58d11.jpg?aki_policy=x_large    93
# https://a0.muscache.com/im/pictures/498b62ad-2375-4f4e-a1b7-f7abcd90a7c0.jpg?aki_policy=x_large    24
# https://a0.muscache.com/im/pictures/40e8ad02-69a4-44b5-beb6-58013d08e780.jpg?aki_policy=x_large    13
# https://a0.muscache.com/im/pictures/4186dbbc-fea5-4818-ac4f-a628980f0640.jpg?aki_policy=x_large    12
# https://a0.muscache.com/im/pictures/d561ccb8-2d89-45b5-aaa5-9d08f4168f41.jpg?aki_policy=x_large    10
#                                                                                                    ..
# https://a0.muscache.com/im/pictures/0d1bc391-b90c-49ea-a9bc-a8bd579d6a4b.jpg?aki_policy=x_large     1
# https://a0.muscache.com/im/pictures/134d5d9f-7e95-4c67-b807-1c2bf4d6370e.jpg?aki_policy=x_large     1
# https://a0.muscache.com/im/pictures/70597ed2-a3aa-489b-8ea7-16d7e3503dfe.jpg?aki_policy=x_large     1
# https://a0.muscache.com/im/pictures/d0eafc36-e15f-4950-9657-cbb83f270a99.jpg?aki_policy=x_large     1
# https://a0.muscache.com/im/pictures/7b170cfc-875f-4510-85f5-4cc2f61e47c4.jpg?aki_policy=x_large     1
# Name: Airbnb Listing Main Image URL, Length: 46341, dtype: int64
# 7846582ha    1
# 4643131ha    1
# 4699785ha    1
# 4700184ha    1
# 4700769ha    1
#             ..
# 1222637      1
# 1222976      1
# 1224373      1
# 1238079      1
# 967007       1
# Name: HomeAway Property ID, Length: 2321, dtype: int64
# travelmob-810190w                 596
# Onlyapartments-S-A--1223592u       32
# Your-Rentals-1408521u              22
# Emerge-Rental-Network-1432218w     14
# Flat4Day-326889u                    4
# CanadaStays-970970w                 1
# VacayHome-Connect-1032563w          1
# VacayHome-Connect-808098w           1
# Travelopo-322402u                   1
# Name: HomeAway Property Manager, dtype: int64
# https://www.vrbo.com/7846582ha                         1
# https://www.homeaway.com/vacation-rental/p4643131ha    1
# https://www.homeaway.com/vacation-rental/p4699785ha    1
# https://www.homeaway.com/vacation-rental/p4700184ha    1
# https://www.homeaway.com/vacation-rental/p4700769ha    1
#                                                       ..
# https://www.homeaway.com/vacation-rental/p1222637      1
# https://www.homeaway.com/vacation-rental/p1222976      1
# https://www.homeaway.com/vacation-rental/p1224373      1
# https://www.homeaway.com/vacation-rental/p1238079      1
# https://www.homeaway.com/vacation-rental/p967007       1
# Name: HomeAway Listing URL, Length: 2321, dtype: int64
# https://media.vrbo.com/lodging/38000000/37110000/37108900/37108883/531d1cbb.c10.jpg    1
# https://odis.homeaway.com/odis/listing/eb278d9e-e5cb-4c9b-976d-0efa4c5ff0cc.c10.jpg    1
# https://odis.homeaway.com/odis/listing/619d63ff-0f65-4f53-b50b-c4b1bb15c754.c10.jpg    1
# https://imagesus-ssl.homeaway.com/mda01/2d02bb1a-33c4-4840-bcb2-e6b30c92a06f.1.10      1
# https://imagesus-ssl.homeaway.com/mda01/674ced79-9602-49c4-8c11-1d10548e66a8.1.10      1
#                                                                                       ..
# https://odis.homeaway.com/odis/listing/cdfe9409-7eb6-4245-a7e9-fa51f0d75b49.c10.jpg    1
# https://media.vrbo.com/lodging/36000000/35280000/35273200/35273102/a7958e11.c10.jpg    1
# https://media.vrbo.com/lodging/40000000/39880000/39872300/39872291/2eed920a.c10.jpg    1
# https://media.vrbo.com/lodging/43000000/42390000/42381200/42381188/2075fd7b.c10.jpg    1
# https://odis.homeaway.com/odis/listing/ec7ae29c-e247-4eb7-8cca-233e5a3602fb.c10.jpg    1
# Name: HomeAway Listing Main Image URL, Length: 2320, dtype: int64

# %%
rnt_df.head()
# Out:
#        Corte    RNT                                          CATEGORIA  \
# 0 2019-12-31  63361                                  Agencia de viajes
# 1 2019-12-31  63740  Otros tipos de hospedaje turísticos no permane...
# 2 2019-12-31  48800          Establecimientos de alojamiento turístico
# 3 2019-12-31  21900                                  Agencia de viajes
# 4 2019-12-31  39874          Establecimientos de alojamiento turístico
#
#                                      SUB_DESCRIPCION   LOCALIDAD  \
# 0                      Agencias de viajes mayoristas        Suba
# 1  Otros tipos de hospedaje turísticos no permane...    Engativá
# 2                                             Hostal   Chapinero
# 3                      Agencias de viajes operadoras  Candelaria
# 4                                              Hotel   Chapinero
#
#            BARRIO  NUMERO_EMPLEADOS  CANTIDAD_HABITACIONES  CANTIDAD_CAMAS  \
# 0        Britalia                 3                    NaN             NaN
# 1         Bolivia                 0                    2.0             2.0
# 2  Quinta camacho                 2                    4.0            16.0
# 3    La concordia                 0                    NaN             NaN
# 4           Marly                 0                   15.0            17.0
#
#     LATITUD   LONGITUD
# 0  4.746649 -74.057329
# 1  4.706205 -74.124733
# 2  4.653318 -74.060383
# 3  4.597517 -74.070779
# 4  4.634686 -74.064283

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49953 entries, 0 to 49952
# Data columns (total 56 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Property ID                      49953 non-null  object
#  1   Listing Title                    49924 non-null  object
#  2   Property Type                    49917 non-null  object
#  3   Listing Type                     49926 non-null  object
#  4   Created Date                     48135 non-null  object
#  5   Last Scraped Date                49953 non-null  object
#  6   Country                          49953 non-null  object
#  7   Latitude                         49953 non-null  float64
#  8   Longitude                        49953 non-null  float64
#  9   State                            0 non-null      float64
#  10  City                             49953 non-null  object
#  11  Zipcode                          0 non-null      float64
#  12  Neighborhood                     49621 non-null  object
#  13  Metropolitan Statistical Area    0 non-null      float64
#  14  Currency Native                  47780 non-null  object
#  15  Average Daily Rate (USD)         12863 non-null  float64
#  16  Average Daily Rate (Native)      12536 non-null  float64
#  17  Annual Revenue LTM (USD)         49799 non-null  float64
#  18  Annual Revenue LTM (Native)      47986 non-null  float64
#  19  Occupancy Rate LTM               12865 non-null  float64
#  20  Number of Bookings LTM           49799 non-null  float64
#  21  Count Reservation Days LTM       12865 non-null  float64
#  22  Count Available Days LTM         12865 non-null  float64
#  23  Count Blocked Days LTM           12865 non-null  float64
#  24  Bedrooms                         49912 non-null  float64
#  25  Bathrooms                        49837 non-null  float64
#  26  Max Guests                       49882 non-null  float64
#  27  Calendar Last Updated            34394 non-null  object
#  28  Response Rate                    41984 non-null  float64
#  29  Airbnb Superhost                 47780 non-null  object
#  30  HomeAway Premier Partner         1757 non-null   object
#  31  Cancellation Policy              49550 non-null  object
#  32  Security Deposit (USD)           5400 non-null   float64
#  33  Security Deposit (Native)        5116 non-null   float64
#  34  Cleaning Fee (USD)               19463 non-null  float64
#  35  Cleaning Fee (Native)            12002 non-null  float64
#  36  Extra People Fee (USD)           9712 non-null   float64
#  37  Extra People Fee (Native)        8947 non-null   float64
#  38  Published Nightly Rate (USD)     48106 non-null  float64
#  39  Published Monthly Rate (USD)     28926 non-null  float64
#  40  Published Weekly Rate (USD)      28955 non-null  float64
#  41  Check-in Time                    40772 non-null  object
#  42  Checkout Time                    24968 non-null  object
#  43  Minimum Stay                     49642 non-null  float64
#  44  Number of Reviews                49723 non-null  float64
#  45  Number of Photos                 49678 non-null  float64
#  46  Instantbook Enabled              49953 non-null  bool
#  47  Overall Rating                   21633 non-null  float64
#  48  Airbnb Property ID               48135 non-null  float64
#  49  Airbnb Host ID                   48100 non-null  float64
#  50  Airbnb Listing URL               48135 non-null  object
#  51  Airbnb Listing Main Image URL    47938 non-null  object
#  52  HomeAway Property ID             2321 non-null   object
#  53  HomeAway Property Manager        672 non-null    object
#  54  HomeAway Listing URL             2321 non-null   object
#  55  HomeAway Listing Main Image URL  2320 non-null   object
# dtypes: bool(1), float64(33), object(22)
# memory usage: 21.0+ MB

# %%
rnt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30230 entries, 0 to 30229
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Corte                  30230 non-null  datetime64[ns]
#  1   RNT                    30230 non-null  int64
#  2   CATEGORIA              30230 non-null  object
#  3   SUB_DESCRIPCION        30230 non-null  object
#  4   LOCALIDAD              27715 non-null  object
#  5   BARRIO                 27715 non-null  object
#  6   NUMERO_EMPLEADOS       30230 non-null  int64
#  7   CANTIDAD_HABITACIONES  23954 non-null  float64
#  8   CANTIDAD_CAMAS         23954 non-null  float64
#  9   LATITUD                27717 non-null  float64
#  10  LONGITUD               27717 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(4)
# memory usage: 2.5+ MB

# %%
# Data Cleaning
print(len(airbnb_df))
airbnb_df.isna().sum()
# Out:
# 49953
# Property ID                            0
# Listing Title                         29
# Property Type                         36
# Listing Type                          27
# Created Date                        1818
# Last Scraped Date                      0
# Country                                0
# Latitude                               0
# Longitude                              0
# State                              49953
# City                                   0
# Zipcode                            49953
# Neighborhood                         332
# Metropolitan Statistical Area      49953
# Currency Native                     2173
# Average Daily Rate (USD)           37090
# Average Daily Rate (Native)        37417
# Annual Revenue LTM (USD)             154
# Annual Revenue LTM (Native)         1967
# Occupancy Rate LTM                 37088
# Number of Bookings LTM               154
# Count Reservation Days LTM         37088
# Count Available Days LTM           37088
# Count Blocked Days LTM             37088
# Bedrooms                              41
# Bathrooms                            116
# Max Guests                            71
# Calendar Last Updated              15559
# Response Rate                       7969
# Airbnb Superhost                    2173
# HomeAway Premier Partner           48196
# Cancellation Policy                  403
# Security Deposit (USD)             44553
# Security Deposit (Native)          44837
# Cleaning Fee (USD)                 30490
# Cleaning Fee (Native)              37951
# Extra People Fee (USD)             40241
# Extra People Fee (Native)          41006
# Published Nightly Rate (USD)        1847
# Published Monthly Rate (USD)       21027
# Published Weekly Rate (USD)        20998
# Check-in Time                       9181
# Checkout Time                      24985
# Minimum Stay                         311
# Number of Reviews                    230
# Number of Photos                     275
# Instantbook Enabled                    0
# Overall Rating                     28320
# Airbnb Property ID                  1818
# Airbnb Host ID                      1853
# Airbnb Listing URL                  1818
# Airbnb Listing Main Image URL       2015
# HomeAway Property ID               47632
# HomeAway Property Manager          49281
# HomeAway Listing URL               47632
# HomeAway Listing Main Image URL    47633
# dtype: int64

# %%
airbnb_df = airbnb_df.drop(columns=['State', 
                                    'Zipcode',
                                    'Metropolitan Statistical Area',
                                    'HomeAway Premier Partner',
                                    'Security Deposit (USD)',
                                    'Security Deposit (Native)',
                                    'Extra People Fee (USD)',
                                    'Extra People Fee (Native)',
                                    'HomeAway Property ID',
                                    'HomeAway Property Manager',
                                    'HomeAway Listing URL',
                                    'HomeAway Listing Main Image URL'
                                    ])
airbnb_df.dropna()
airbnb_df.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-679594ec41c5> in <module>()
#      10                                     'HomeAway Property Manager',
#      11                                     'HomeAway Listing URL',
# ---> 12                                     'HomeAway Listing Main Image URL'
#      13                                     ])
#      14 airbnb_df.dropna()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['State' 'Zipcode' 'Metropolitan Statistical Area'\n 'HomeAway Premier Partner' 'Security Deposit (USD)'\n 'Security Deposit (Native)' 'Extra People Fee (USD)'\n 'Extra People Fee (Native)' 'HomeAway Property ID'\n 'HomeAway Property Manager' 'HomeAway Listing URL'\n 'HomeAway Listing Main Image URL'] not found in axis"

# %%
print(len(rnt_df))
rnt_df.isna().sum()
# Out:
# 30230
# Corte                       0
# RNT                         0
# CATEGORIA                   0
# SUB_DESCRIPCION             0
# LOCALIDAD                2515
# BARRIO                   2515
# NUMERO_EMPLEADOS            0
# CANTIDAD_HABITACIONES    6276
# CANTIDAD_CAMAS           6276
# LATITUD                  2513
# LONGITUD                 2513
# dtype: int64
