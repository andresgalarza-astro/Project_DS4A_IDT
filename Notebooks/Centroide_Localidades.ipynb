# %%
import pandas as pd
import numpy                 as np
import geopandas             as gpd
from pathlib import Path

# %%
file_path= 'D:/JUAN CAMILO/DS4A/Proyecto FInal/locashp/Loca.shp'

# %%
MapaLocalidades = gpd.read_file(file_path)
MapaLocalidades.head()
# Out:
#             LocNombre           LocAAdmini       LocArea LocCodigo  \
# 0      ANTONIO NARIÑO  Acuerdo 117 de 2003  4.879543e+06        15
# 1          TUNJUELITO  Acuerdo 117 de 2003  9.910940e+06        06
# 2  RAFAEL URIBE URIBE  Acuerdo 117 de 2003  1.383408e+07        18
# 3          CANDELARIA  Acuerdo 117 de 2003  2.060243e+06        17
# 4      BARRIOS UNIDOS    Acuerdo 8 de 1977  1.190345e+07        12
#
#    SHAPE_Leng  SHAPE_Area                                           geometry
# 0    0.108973    0.000397  POLYGON ((-74.13075 4.59335, -74.12917 4.59327...
# 1    0.210542    0.000807  POLYGON ((-74.13777 4.59489, -74.13165 4.59363...
# 2    0.174513    0.001126  POLYGON ((-74.12803 4.59254, -74.12777 4.59233...
# 3    0.067158    0.000168  POLYGON ((-74.06621 4.60317, -74.06620 4.60317...
# 4    0.121180    0.000969  POLYGON ((-74.05725 4.68684, -74.06249 4.65594...

# %%
dic_Localidades={'TEUSAQUILLO':'Teusaquillo',
                'USAQUEN':'Usaquén',
                'CHAPINERO':'Chapinero',
                'SANTA FE':'Santa Fe',
                'SAN CRISTOBAL':'San Cristobal',
                'USME':'Usme',
                'TUNJUELITO':'Tunjuelito',
                'BOSA':'Bosa',
                'KENNEDY':'Kennedy',
                'FONTIBON':'Fontibón',
                'ENGATIVA':'Engativá',
                'SUBA':'Suba',
                'BARRIOS UNIDOS':'Barrios Unidos',
                'TEUSAQUILLO':'Teusaquillo',
                'LOS MARTIRES':'Los Mártires',
                'ANTONIO NARIÑO':'Antonio Nariño',
                'PUENTE ARANDA':'Puente Aranda',
                'CANDELARIA':'La Candelaria',
                'RAFAEL URIBE URIBE':'Rafael Uribe Uribe',
                'CIUDAD BOLIVAR':'Ciudad Bolivar',
                 'SUMAPAZ':'Sumapaz'
}

MapaLocalidades['Nombre_Localidad']=MapaLocalidades['LocNombre'].replace(dic_Localidades)

# %%
MapaLocalidades["lon"] = MapaLocalidades["geometry"].centroid.x
MapaLocalidades["lat"] = MapaLocalidades["geometry"].centroid.y
MapaLocalidades
# Out:
# C:\Users\JUAN CAMILO\AppData\Local\Temp\ipykernel_9716\984621208.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   MapaLocalidades["lon"] = MapaLocalidades["geometry"].centroid.x
# C:\Users\JUAN CAMILO\AppData\Local\Temp\ipykernel_9716\984621208.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#
# 7   POLYGON ((-74.07283 4.61542, -74.07311 4.61480...        Los Mártires
# 8   POLYGON ((-74.20584 4.26966, -74.20584 4.26966...             Sumapaz
# 9   POLYGON ((-74.01116 4.66459, -74.01117 4.66460...             Usaquén
# 10  POLYGON ((-74.01116 4.66459, -74.01154 4.66461...           Chapinero
# 11  POLYGON ((-73.99446 4.61425, -73.99457 4.61414...            Santa Fe
# 12  POLYGON ((-74.02900 4.55830, -74.02930 4.55821...       San Cristobal
# 13  POLYGON ((-74.05597 4.50832, -74.05611 4.50822...                Usme
# 14  POLYGON ((-74.21092 4.38691, -74.21114 4.38750...      Ciudad Bolivar
# 15  POLYGON ((-74.18567 4.64705, -74.18480 4.64497...                Bosa
# 16  POLYGON ((-74.18567 4.64705, -74.18527 4.64699...             Kennedy
# 17  POLYGON ((-74.15857 4.66274, -74.15848 4.66279...            Fontibón
# 18  POLYGON ((-74.15547 4.71798, -74.15547 4.71798...            Engativá
# 19  POLYGON ((-74.03450 4.82547, -74.03478 4.82418...                Suba
#
#           lon       lat
# 0  -74.102842  4.588771
# 1  -74.135989  4.574841
# 2  -74.113363  4.566477
# 3  -74.072071  4.596605
# 4  -74.073552  4.669567
# 5  -74.085769  4.641174
# 6  -74.111580  4.616245
# 7  -74.087948  4.607156
# 8  -74.256979  4.036569
# 9  -74.027882  4.741929
# 10 -74.036939  4.644925
# 11 -74.036218  4.593973
# 12 -74.066073  4.548749
# 13 -74.142806  4.390025
# 14 -74.161959  4.482460
# 15 -74.194389  4.621780
# 16 -74.152668  4.630347
# 17 -74.140151  4.678183
# 18 -74.113188  4.701126
# 19 -74.075845  4.763208

# %%
df2= MapaLocalidades[['Nombre_Localidad','lon','lat']]
df2
# Out:
#       Nombre_Localidad        lon       lat
# 0       Antonio Nariño -74.102842  4.588771
# 1           Tunjuelito -74.135989  4.574841
# 2   Rafael Uribe Uribe -74.113363  4.566477
# 3        La Candelaria -74.072071  4.596605
# 4       Barrios Unidos -74.073552  4.669567
# 5          Teusaquillo -74.085769  4.641174
# 6        Puente Aranda -74.111580  4.616245
# 7         Los Mártires -74.087948  4.607156
# 8              Sumapaz -74.256979  4.036569
# 9              Usaquén -74.027882  4.741929
# 10           Chapinero -74.036939  4.644925
# 11            Santa Fe -74.036218  4.593973
# 12       San Cristobal -74.066073  4.548749
# 13                Usme -74.142806  4.390025
# 14      Ciudad Bolivar -74.161959  4.482460
# 15                Bosa -74.194389  4.621780
# 16             Kennedy -74.152668  4.630347
# 17            Fontibón -74.140151  4.678183
# 18            Engativá -74.113188  4.701126
# 19                Suba -74.075845  4.763208

# %%
filepath = Path('D:/JUAN CAMILO/DS4A/Proyecto FInal/Bases de Datos/CentroideLoc.csv')
filepath.parent.mkdir(parents=True, exist_ok=True) 
df2.to_csv(filepath)
