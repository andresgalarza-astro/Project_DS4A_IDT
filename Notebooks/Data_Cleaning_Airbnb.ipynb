# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.graph_objs as go 
import plotly.express as px
from google.colab import drive

# %%
# Connect Drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Read Datasets
df=pd.read_csv('gdrive/My Drive/DS4A/Project/Datasets/4. Base de datos de establecimientos AirBnb en Bogotá 2020-.csv', 
               parse_dates = [4, 5, 27], 
               dtype = {'Currency Native': str,
                        'Check-in Time': str,
                        'Checkout Time': str,
                        'Airbnb Listing URL': str,
                        'Airbnb Listing Main Image URL': str})
df['Airbnb Superhost'] = df['Airbnb Superhost'].astype(bool)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (29) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49953 entries, 0 to 49952
# Data columns (total 56 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Property ID                      49953 non-null  object
#  1   Listing Title                    49924 non-null  object
#  2   Property Type                    49917 non-null  object
#  3   Listing Type                     49926 non-null  object
#  4   Created Date                     48135 non-null  datetime64[ns]
#  5   Last Scraped Date                49953 non-null  datetime64[ns]
#  6   Country                          49953 non-null  object
#  7   Latitude                         49953 non-null  float64
#  8   Longitude                        49953 non-null  float64
#  9   State                            0 non-null      float64
#  10  City                             49953 non-null  object
#  11  Zipcode                          0 non-null      float64
#  12  Neighborhood                     49621 non-null  object
#  13  Metropolitan Statistical Area    0 non-null      float64
#  14  Currency Native                  47780 non-null  object
#  15  Average Daily Rate (USD)         12863 non-null  float64
#  16  Average Daily Rate (Native)      12536 non-null  float64
#  17  Annual Revenue LTM (USD)         49799 non-null  float64
#  18  Annual Revenue LTM (Native)      47986 non-null  float64
#  19  Occupancy Rate LTM               12865 non-null  float64
#  20  Number of Bookings LTM           49799 non-null  float64
#  21  Count Reservation Days LTM       12865 non-null  float64
#  22  Count Available Days LTM         12865 non-null  float64
#  23  Count Blocked Days LTM           12865 non-null  float64
#  24  Bedrooms                         49912 non-null  float64
#  25  Bathrooms                        49837 non-null  float64
#  26  Max Guests                       49882 non-null  float64
#  27  Calendar Last Updated            34394 non-null  datetime64[ns]
#  28  Response Rate                    41984 non-null  float64
#  29  Airbnb Superhost                 49953 non-null  bool
#  30  HomeAway Premier Partner         1757 non-null   object
#  31  Cancellation Policy              49550 non-null  object
#  32  Security Deposit (USD)           5400 non-null   float64
#  33  Security Deposit (Native)        5116 non-null   float64
#  34  Cleaning Fee (USD)               19463 non-null  float64
#  35  Cleaning Fee (Native)            12002 non-null  float64
#  36  Extra People Fee (USD)           9712 non-null   float64
#  37  Extra People Fee (Native)        8947 non-null   float64
#  38  Published Nightly Rate (USD)     48106 non-null  float64
#  39  Published Monthly Rate (USD)     28926 non-null  float64
#  40  Published Weekly Rate (USD)      28955 non-null  float64
#  41  Check-in Time                    40772 non-null  object
#  42  Checkout Time                    24968 non-null  object
#  43  Minimum Stay                     49642 non-null  float64
#  44  Number of Reviews                49723 non-null  float64
#  45  Number of Photos                 49678 non-null  float64
#  46  Instantbook Enabled              49953 non-null  bool
#  47  Overall Rating                   21633 non-null  float64
#  48  Airbnb Property ID               48135 non-null  float64
#  49  Airbnb Host ID                   48100 non-null  float64
#  50  Airbnb Listing URL               48135 non-null  object
#  51  Airbnb Listing Main Image URL    47938 non-null  object
#  52  HomeAway Property ID             2321 non-null   object
#  53  HomeAway Property Manager        672 non-null    object
#  54  HomeAway Listing URL             2321 non-null   object
#  55  HomeAway Listing Main Image URL  2320 non-null   object
# dtypes: bool(2), datetime64[ns](3), float64(33), object(18)
# memory usage: 20.7+ MB

# %%
# Drop columns with very little information or no information at all
df.drop(['State', 
         'Zipcode', 
         'Metropolitan Statistical Area', 
         'HomeAway Premier Partner',
         'HomeAway Property ID', 
         'HomeAway Property Manager', 
         'HomeAway Listing URL', 
         'HomeAway Listing Main Image URL'], axis = 1, 
        inplace=True)

# %%
# Drop rows of the most important columns
df.dropna(subset=['Listing Title', 
                  'Property Type', 
                  'Listing Type',
                  'Created Date', 
                  'Neighborhood', 
                  'Currency Native',
                  'Number of Bookings LTM',
                  'Cancellation Policy',
                  'Minimum Stay',
                  'Bedrooms',
                  'Bathrooms',
                  'Max Guests',
                  'Cancellation Policy',
                  'Number of Reviews',
                  'Number of Photos',
                  'Airbnb Property ID',
                  'Airbnb Host ID',
                  'Airbnb Listing URL',
                  'Airbnb Listing Main Image URL'],
          inplace = True)

# %%
# Fix Neighborhood names
df['Neighborhood'] = df['Neighborhood'].str.strip()

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Property ID                                    Listing Title  \
# 0  ab-44018885                           Hermosa casa, El nogal
# 1  ab-44019196                     CÓMODO, CENTRAL Y TRANQUILO.
# 2  ab-44020565  Habitación Grande baño privado y terraza. 3piso
# 3  ab-44030858                            Hotel A&M florida 401
# 4  ab-44033318   Habitacion en bogota cerca a el aeropuerto 201
#
#       Property Type     Listing Type Created Date Last Scraped Date   Country  \
# 0  Residential home  Entire home/apt   2020-10-22        2022-02-14  Colombia
# 1        Guesthouse  Entire home/apt   2020-10-09        2022-02-15  Colombia
# 2       Guest suite     Private room   2020-10-25        2022-02-14  Colombia
# 3         Apartment  Entire home/apt   2020-07-17        2021-01-30  Colombia
# 4             House     Private room   2020-10-20        2020-11-04  Colombia
#
#    Latitude  Longitude    City Neighborhood Currency Native  \
# 0   4.66309  -74.05459  Bogotá    Chapinero             COP
# 1   4.63608  -74.07005  Bogotá  Teusaquillo             COP
# 2   4.75203  -74.05508  Bogotá         Suba             COP
# 3   4.70717  -74.12482  Bogotá     Engativa             COP
# 4   4.67015  -74.10249  Bogotá     Engativa             COP
#
#    Average Daily Rate (USD)  Average Daily Rate (Native)  \
# 0                     65.14                     250000.0
# 1                     14.00                      55000.0
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#    Annual Revenue LTM (USD)  Annual Revenue LTM (Native)  Occupancy Rate LTM  \
# 0                     912.0                    3500000.0               0.070
# 1                     784.0                    3080000.0               0.371
# 2                       0.0                          0.0                 NaN
# 3                       0.0                          0.0                 NaN
# 4                       0.0                          0.0                 NaN
#
#    Number of Bookings LTM  Count Reservation Days LTM  \
# 0                     8.0                        14.0
# 1                     7.0                        56.0
# 2                     0.0                         NaN
# 3                     0.0                         NaN
# 4                     0.0                         NaN
#
#    Count Available Days LTM  Count Blocked Days LTM  Bedrooms  Bathrooms  \
# 0                     186.0                    14.0       4.0        3.0
# 1                      95.0                     3.0       1.0        1.0
# 2                       NaN                     NaN       1.0        1.0
# 3                       NaN                     NaN       3.0        1.0
# 4                       NaN                     NaN       1.0        1.0
#
#    Max Guests Calendar Last Updated  Response Rate  Airbnb Superhost  \
# 0         5.0                   NaT            0.0             False
# 1         2.0                   NaT           78.0             False
# 2         1.0                   NaT            0.0             False
# 3         4.0                   NaT           60.0             False
# 4         4.0                   NaT          100.0             False
#
#   Cancellation Policy  Security Deposit (USD)  Security Deposit (Native)  \
# 0            flexible                     NaN                        NaN
# 1            flexible                     NaN                        NaN
# 2            flexible                     NaN                        NaN
# 3            flexible                     NaN                        NaN
# 4            flexible                     NaN                        NaN
#
#    Cleaning Fee (USD)  Cleaning Fee (Native)  Extra People Fee (USD)  \
# 0                 NaN                    NaN                     NaN
# 1                 NaN                    NaN                     NaN
# 2                 NaN                    NaN                     NaN
# 3                 9.0                    NaN                     NaN
# 4                 5.0                    NaN                     NaN
#
#    Extra People Fee (Native)  Published Nightly Rate (USD)  \
# 0                        NaN                          63.0
# 1                        NaN                          14.0
# 2                        NaN                          15.0
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#    Published Monthly Rate (USD)  Published Weekly Rate (USD)  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#        Check-in Time Checkout Time  Minimum Stay  Number of Reviews  \
# 0                NaN           NaN           1.0                0.0
# 1  9:00 AM - 4:00 PM       4:00 PM           3.0                5.0
# 2           Flexible       1:00 AM           1.0                0.0
# 3     After 10:00 AM       6:00 PM           1.0                2.0
# 4      After 3:00 PM           NaN           1.0                0.0
#
#    Number of Photos  Instantbook Enabled  Overall Rating  Airbnb Property ID  \
# 0              11.0                False             NaN          44018885.0
# 1               5.0                 True             5.0          44019196.0
# 2               8.0                False             NaN          44020565.0
# 3              17.0                False             4.5          44030858.0
# 4              17.0                 True             NaN          44033318.0
#
#    Airbnb Host ID                     Airbnb Listing URL  \
# 0     351991717.0  https://www.airbnb.com/rooms/44018885
# 1     352772452.0  https://www.airbnb.com/rooms/44019196
# 2      30434345.0  https://www.airbnb.com/rooms/44020565
# 3     338182528.0  https://www.airbnb.com/rooms/44030858
# 4     264501662.0  https://www.airbnb.com/rooms/44033318
#
#                        Airbnb Listing Main Image URL
# 0  https://a0.muscache.com/im/pictures/496e7391-2...
# 1  https://a0.muscache.com/im/pictures/b3495a0b-6...
# 2  https://a0.muscache.com/im/pictures/25525e57-8...
# 3  https://a0.muscache.com/im/pictures/6f60d777-5...
# 4  https://a0.muscache.com/im/pictures/9c8596b9-d...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46624 entries, 0 to 48134
# Data columns (total 48 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Property ID                    46624 non-null  object
#  1   Listing Title                  46624 non-null  object
#  2   Property Type                  46624 non-null  object
#  3   Listing Type                   46624 non-null  object
#  4   Created Date                   46624 non-null  datetime64[ns]
#  5   Last Scraped Date              46624 non-null  datetime64[ns]
#  6   Country                        46624 non-null  object
#  7   Latitude                       46624 non-null  float64
#  8   Longitude                      46624 non-null  float64
#  9   City                           46624 non-null  object
#  10  Neighborhood                   46624 non-null  object
#  11  Currency Native                46624 non-null  object
#  12  Average Daily Rate (USD)       12496 non-null  float64
#  13  Average Daily Rate (Native)    12492 non-null  float64
#  14  Annual Revenue LTM (USD)       46624 non-null  float64
#  15  Annual Revenue LTM (Native)    46624 non-null  float64
#  16  Occupancy Rate LTM             12496 non-null  float64
#  17  Number of Bookings LTM         46624 non-null  float64
#  18  Count Reservation Days LTM     12496 non-null  float64
#  19  Count Available Days LTM       12496 non-null  float64
#  20  Count Blocked Days LTM         12496 non-null  float64
#  21  Bedrooms                       46624 non-null  float64
#  22  Bathrooms                      46624 non-null  float64
#  23  Max Guests                     46624 non-null  float64
#  24  Calendar Last Updated          31714 non-null  datetime64[ns]
#  25  Response Rate                  41024 non-null  float64
#  26  Airbnb Superhost               46624 non-null  bool
#  27  Cancellation Policy            46624 non-null  object
#  28  Security Deposit (USD)         5218 non-null   float64
#  29  Security Deposit (Native)      5029 non-null   float64
#  30  Cleaning Fee (USD)             18717 non-null  float64
#  31  Cleaning Fee (Native)          11846 non-null  float64
#  32  Extra People Fee (USD)         9527 non-null   float64
#  33  Extra People Fee (Native)      8855 non-null   float64
#  34  Published Nightly Rate (USD)   44933 non-null  float64
#  35  Published Monthly Rate (USD)   27902 non-null  float64
#  36  Published Weekly Rate (USD)    27931 non-null  float64
#  37  Check-in Time                  39615 non-null  object
#  38  Checkout Time                  24458 non-null  object
#  39  Minimum Stay                   46624 non-null  float64
#  40  Number of Reviews              46624 non-null  float64
#  41  Number of Photos               46624 non-null  float64
#  42  Instantbook Enabled            46624 non-null  bool
#  43  Overall Rating                 21183 non-null  float64
#  44  Airbnb Property ID             46624 non-null  float64
#  45  Airbnb Host ID                 46624 non-null  float64
#  46  Airbnb Listing URL             46624 non-null  object
#  47  Airbnb Listing Main Image URL  46624 non-null  object
# dtypes: bool(2), datetime64[ns](3), float64(30), object(13)
# memory usage: 16.8+ MB

# %%
property_df = pd.DataFrame(df['Property Type'].value_counts()).reset_index().sort_values('Property Type', ascending = False).head(10).sort_values('Property Type')
ax = px.bar(property_df, x='Property Type', y='index', labels = {'Property Type':'# of Establishments', 
                                                              'index':'Property Type'}, title = 'Airbnb Establishments by Property Type')
ax.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d5820f65-32b1-4bf5-814e-d81de6c19202" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5820f65-32b1-4bf5-814e-d81de6c19202")) {                    Plotly.newPlot(                        "d5820f65-32b1-4bf5-814e-d81de6c19202",                        [{"alignmentgroup":"True","hovertemplate":"# of Establishments=%{x}<br>Property Type=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[501,746,1379,1491,1549,2035,2546,2722,13297,15729],"xaxis":"x","y":["Room in boutique hotel","Bed and breakfast","Serviced apartment","Loft","Condominium","Condominium (condo)","House","Residential home","Rental unit","Apartment"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}}," ...

# %%
property_df = pd.DataFrame(df['Neighborhood'].value_counts()).reset_index().sort_values('Neighborhood', ascending = False).head(10).sort_values('Neighborhood')
ax = px.bar(property_df, x='Neighborhood', y='index', labels = {'Neighborhood':'# of Establishments', 
                                                              'index':'Neighborhood'}, title = 'Airbnb Establishments by Neighborhood')
ax.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="307a1712-e334-4a54-bb6b-c7f0cffc4d55" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("307a1712-e334-4a54-bb6b-c7f0cffc4d55")) {                    Plotly.newPlot(                        "307a1712-e334-4a54-bb6b-c7f0cffc4d55",                        [{"alignmentgroup":"True","hovertemplate":"# of Establishments=%{x}<br>Neighborhood=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[538,1437,2154,2170,2746,4132,5939,6492,8851,10885],"xaxis":"x","y":["Puente Aranda","Kennedy","Barrios Unidos","Fontibon","Engativa","Santa Fe","Suba","Teusaquillo","Usaquen","Chapinero"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":tru ...

# %%
df[['Average Daily Rate (USD)', 'Average Daily Rate (Native)', 'Published Nightly Rate (USD)', 'Published Monthly Rate (USD)', 'Published Weekly Rate (USD)']].describe()
# Out:
#        Average Daily Rate (USD)  Average Daily Rate (Native)  \
# count              12496.000000                 1.249200e+04
# mean                  36.039784                 8.553411e+04
# std                   46.266056                 1.015402e+05
# min                    5.000000                 9.000000e+00
# 25%                   17.277500                 1.372275e+02
# 50%                   26.225000                 6.954913e+04
# 75%                   41.960000                 1.190094e+05
# max                 3309.330000                 2.500000e+06
#
#        Published Nightly Rate (USD)  Published Monthly Rate (USD)  \
# count                  44933.000000                  2.790200e+04
# mean                      66.202791                  2.949613e+03
# std                     1453.689461                  7.225140e+04
# min                        0.000000                  0.000000e+00
# 25%                       13.000000                  4.130000e+02
# 50%                       23.000000                  7.000000e+02
# 75%                       42.000000                  1.236000e+03
# max                   236900.000000                  6.633200e+06
#
#        Published Weekly Rate (USD)
# count                 2.793100e+04
# mean                  7.672199e+02
# std                   1.935749e+04
# min                   0.000000e+00
# 25%                   1.050000e+02
# 50%                   1.750000e+02
# 75%                   3.150000e+02
# max                   1.658300e+06

# %%
df['Property Type'].unique()
# Out:
# array(['Residential home', 'Guesthouse', 'Guest suite', 'Apartment',
#        'House', 'Serviced apartment', 'Room in hotel', 'Rental unit',
#        'Condominium', 'Loft', 'Bed and breakfast', 'Tiny house',
#        'Room in boutique hotel', 'Room in aparthotel', 'Cottage',
#        'Condominium (condo)', 'Hostel', 'Farm stay', 'Dome house',
#        'Cabin', 'Campsite', 'Townhouse', 'Casa particular', 'Villa',
#        'Nature lodge', 'Barn', 'Room in serviced apartment', 'Castle',
#        'Earth house', 'Camper/rv', 'Private room', 'Place', 'Shared room',
#        'Tent', 'Tower', 'Vacation home', 'Chalet',
#        'Casa particular (cuba)', 'Houseboat', 'Treehouse',
#        'Room in hostel', 'Bus', 'Dorm', 'Pension (south korea)', 'Plane',
#        'Room in bed and breakfast', 'Hotel',
#        'Hotel room in serviced apartment', 'Boutique hotel', 'Pension',
#        'Ryokan (japan)', 'Entire apartment', 'Private room in apartment',
#        'Bed & Breakfast', 'Private room in bed and breakfast', 'Boat',
#        'In-law', 'Bed &amp; Breakfast', 'Entire house',
#        'Private room in house', 'Car', 'Timeshare',
#        'Private room in chalet', 'Other', 'Bungalow', 'Tipi',
#        'Private room in condominium', 'Entire serviced apartment',
#        'Entire in-law', 'Entire loft', 'Entire condominium', 'Igloo',
#        'Hut', 'Shared room in apartment', 'Private room in dorm',
#        'Private room in bed & breakfast', 'Entire place', 'Yurt',
#        'Entire bed & breakfast', 'Private room in guesthouse',
#        'Entire Floor', 'Private room in hostel',
#        'Private room in serviced apartment', 'Floor', 'Entire guesthouse',
#        'Shared room in bed & breakfast', 'Shared room in guesthouse',
#        'Entire cabin', 'Home/apt', 'Hotel room in hostel',
#        'Room in pension (south korea)', 'Resort',
#        'Room in casa particular (cuba)', 'Room in nature lodge',
#        'Room in condominium', 'Camper/RV', 'Kezhan', 'Entire townhouse',
#        'Pension (Korea)', 'Aparthotel', 'Shared room in hostel',
#        'Shared room in condominium', 'Private room in guest suite',
#        'Private room in townhouse', 'Private room in boutique hotel',
#        'Heritage hotel (india)', 'Shared room in house', 'Entire dorm',
#        'Shared room in bed and breakfast', 'Private room in loft',
#        'Private room in casa particular', 'Entire guest suite', 'Cave',
#        'Entire villa', 'Entire vacation home'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46624 entries, 0 to 48134
# Data columns (total 48 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Property ID                    46624 non-null  object
#  1   Listing Title                  46624 non-null  object
#  2   Property Type                  46624 non-null  object
#  3   Listing Type                   46624 non-null  object
#  4   Created Date                   46624 non-null  datetime64[ns]
#  5   Last Scraped Date              46624 non-null  datetime64[ns]
#  6   Country                        46624 non-null  object
#  7   Latitude                       46624 non-null  float64
#  8   Longitude                      46624 non-null  float64
#  9   City                           46624 non-null  object
#  10  Neighborhood                   46624 non-null  object
#  11  Currency Native                46624 non-null  object
#  12  Average Daily Rate (USD)       12496 non-null  float64
#  13  Average Daily Rate (Native)    12492 non-null  float64
#  14  Annual Revenue LTM (USD)       46624 non-null  float64
#  15  Annual Revenue LTM (Native)    46624 non-null  float64
#  16  Occupancy Rate LTM             12496 non-null  float64
#  17  Number of Bookings LTM         46624 non-null  float64
#  18  Count Reservation Days LTM     12496 non-null  float64
#  19  Count Available Days LTM       12496 non-null  float64
#  20  Count Blocked Days LTM         12496 non-null  float64
#  21  Bedrooms                       46624 non-null  float64
#  22  Bathrooms                      46624 non-null  float64
#  23  Max Guests                     46624 non-null  float64
#  24  Calendar Last Updated          31714 non-null  datetime64[ns]
#  25  Response Rate                  41024 non-null  float64
#  26  Airbnb Superhost               46624 non-null  bool
#  27  Cancellation Policy            46624 non-null  object
#  28  Security Deposit (USD)         5218 non-null   float64
#  29  Security Deposit (Native)      5029 non-null   float64
#  30  Cleaning Fee (USD)             18717 non-null  float64
#  31  Cleaning Fee (Native)          11846 non-null  float64
#  32  Extra People Fee (USD)         9527 non-null   float64
#  33  Extra People Fee (Native)      8855 non-null   float64
#  34  Published Nightly Rate (USD)   44933 non-null  float64
#  35  Published Monthly Rate (USD)   27902 non-null  float64
#  36  Published Weekly Rate (USD)    27931 non-null  float64
#  37  Check-in Time                  39615 non-null  object
#  38  Checkout Time                  24458 non-null  object
#  39  Minimum Stay                   46624 non-null  float64
#  40  Number of Reviews              46624 non-null  float64
#  41  Number of Photos               46624 non-null  float64
#  42  Instantbook Enabled            46624 non-null  bool
#  43  Overall Rating                 21183 non-null  float64
#  44  Airbnb Property ID             46624 non-null  float64
#  45  Airbnb Host ID                 46624 non-null  float64
#  46  Airbnb Listing URL             46624 non-null  object
#  47  Airbnb Listing Main Image URL  46624 non-null  object
# dtypes: bool(2), datetime64[ns](3), float64(30), object(13)
# memory usage: 16.8+ MB

# %%
df.describe()
# Out:
#            Latitude     Longitude  Average Daily Rate (USD)  \
# count  46624.000000  46624.000000              12496.000000
# mean       4.669237    -74.070420                 36.039784
# std        0.042899      0.028844                 46.266056
# min        4.524440    -74.213190                  5.000000
# 25%        4.638133    -74.080025                 17.277500
# 50%        4.667020    -74.065075                 26.225000
# 75%        4.699039    -74.051840                 41.960000
# max        4.823085    -74.003550               3309.330000
#
#        Average Daily Rate (Native)  Annual Revenue LTM (USD)  \
# count                 1.249200e+04              46624.000000
# mean                  8.553411e+04                427.192605
# std                   1.015402e+05               1627.241514
# min                   9.000000e+00                  0.000000
# 25%                   1.372275e+02                  0.000000
# 50%                   6.954913e+04                  0.000000
# 75%                   1.190094e+05                 40.000000
# max                   2.500000e+06              71374.000000
#
#        Annual Revenue LTM (Native)  Occupancy Rate LTM  \
# count                 4.662400e+04        12496.000000
# mean                  9.816745e+05            0.372645
# std                   4.148037e+06            0.265182
# min                   0.000000e+00            0.032000
# 25%                   0.000000e+00            0.136000
# 50%                   0.000000e+00            0.325000
# 75%                   3.162500e+02            0.567000
# max                   2.735986e+08            1.000000
#
#        Number of Bookings LTM  Count Reservation Days LTM  \
# count            46624.000000                12496.000000
# mean                 3.685226                   43.863796
# std                 10.985719                   52.064495
# min                  0.000000                    1.000000
# 25%                  0.000000                    8.000000
# 50%                  0.000000                   24.000000
# 75%                  1.000000                   60.000000
# max                182.000000                  343.000000
#
#        Count Available Days LTM  Count Blocked Days LTM      Bedrooms  \
# count              12496.000000            12496.000000  46624.000000
# mean                  65.184699               24.054097      1.450240
# std                   56.213300               35.964147      1.603025
# min                    0.000000                0.000000      0.000000
# 25%                   26.000000                0.000000      1.000000
# 50%                   48.000000                5.000000      1.000000
# 75%                   90.000000               35.000000      2.000000
# max                  333.000000              252.000000     50.000000
#
#           Bathrooms    Max Guests  Response Rate  Security Deposit (USD)  \
# count  46624.000000  46624.000000   41024.000000             5218.000000
# mean       1.473769      2.839417      71.600990              223.156957
# std        1.277604      2.168881      40.855422              325.335317
# min        0.000000      1.000000       0.000000               52.000000
# 25%        1.000000      2.000000      44.000000              101.000000
# 50%        1.000000      2.000000     100.000000              150.000000
# 75%        2.000000      4.000000     100.000000              218.250000
# max       50.000000     16.000000     100.000000             5253.000000
#
#        Security Deposit (Native)  Cleaning Fee (USD)  Cleaning Fee (Native)  \
# count               5.029000e+03        18717.000000           1.184600e+04
# mean                2.215291e+05           17.554095           1.409081e+04
# std                 7.537618e+05           88.314257           2.768962e+04
# min                 5.200000e+01            1.000000           1.000000e+00
# 25%                 1.040000e+02            8.000000           1.500000e+01
# 50%                 2.500000e+02           13.000000           2.600000e+01
# 75%                 3.000000e+05           20.000000           2.108250e+04
# max                 1.593174e+07         6850.000000           1.000001e+06
#
#        Extra People Fee (USD)  Extra People Fee (Native)  \
# count             9527.000000                8855.000000
# mean                12.794269               17201.497685
# std                 12.830198               29784.699852
# min                  1.000000                   1.000000
# 25%                  7.000000                  10.000000
# 50%                 10.000000                  40.000000
# 75%                 15.000000               30000.000000
# max                300.000000              850000.000000
#
#        Published Nightly Rate (USD)  Published Monthly Rate (USD)  \
# count                  44933.000000                  2.790200e+04
# mean                      66.202791                  2.949613e+03
# std                     1453.689461                  7.225140e+04
# min                        0.000000                  0.000000e+00
# 25%                       13.000000                  4.130000e+02
# 50%                       23.000000                  7.000000e+02
# 75%                       42.000000                  1.236000e+03
# max                   236900.000000                  6.633200e+06
#
#        Published Weekly Rate (USD)  Minimum Stay  Number of Reviews  \
# count                 2.793100e+04  46624.000000       46624.000000
# mean                  7.672199e+02      5.561749           5.972525
# std                   1.935749e+04     20.370970          20.143436
# min                   0.000000e+00      1.000000           0.000000
# 25%                   1.050000e+02      1.000000           0.000000
# 50%                   1.750000e+02      1.000000           0.000000
# 75%                   3.150000e+02      3.000000           3.000000
# max                   1.658300e+06    569.000000        1470.000000
#
#        Number of Photos  Overall Rating  Airbnb Property ID  Airbnb Host ID
# count      46624.000000    21183.000000        4.662400e+04    4.662400e+04
# mean          14.339546        4.586569        8.860627e+14    1.366137e+08
# std           15.110886        0.740084        2.179328e+16    1.086034e+08
# min            1.000000        1.000000        6.627000e+03    7.061000e+03
# 25%            6.000000        4.500000        1.754520e+07    4.118952e+07
# 50%           10.000000        4.800000        2.793097e+07    1.156870e+08
# 75%           17.000000        5.000000        3.982083e+07    2.135242e+08
# max          199.000000        5.000000        5.493036e+17    4.412079e+08

# %%
# Check values for every column
for col in df.columns:
  print(df[col].value_counts())
# Out:
# ab-44018885    1
# ab-37399094    1
# ab-37414617    1
# ab-37415637    1
# ab-37421063    1
#               ..
# ab-31389901    1
# ab-31390095    1
# ab-31390977    1
# ab-31391312    1
# ab-23918318    1
# Name: Property ID, Length: 46624, dtype: int64
# Habitación privada                                  73
# Habitación                                          50
# Bogotá Departamento                                 43
# Apartamento                                         32
# Habitación con baño privado                         31
#                                                     ..
# Lindo y acogedor apartamento en Chapinero            1
# Sin pagar mas, con lo necesario para tu estadía.     1
# lorena's home!                                       1
# Apartamento kennedy                                  1
# Grandiosa Habitación, cerca al AEROPUERTO            1
# Name: Listing Title, Length: 43285, dtype: int64
# Apartment               15729
# Rental unit             13297
# Residential home         2722
# House                    2546
# Condominium (condo)      2035
#                         ...
# Hotel room in hostel        1
# Car                         1
# Yurt                        1
# Treehouse                   1
# Entire vacation home        1
# Name: Property Type, Length: 115, dtype: int64
# Private room       22861
# Entire home/apt    22436
# Shared room         1089
# Hotel room           238
# Name: Listing Type, dtype: int64
# 2019-12-13    815
# 2019-02-25    468
# 2020-10-21    341
# 2020-10-22    319
# 2018-06-29    235
#              ...
# 2012-12-04      1
# 2012-12-07      1
# 2012-12-13      1
# 2020-05-13      1
# 2013-04-16      1
# Name: Created Date, Length: 2909, dtype: int64
# 2022-02-14    16056
# 2022-02-15     1526
# 2020-01-29     1307
# 2022-02-13      977
# 2019-10-15      258
#               ...
# 2016-06-23        1
# 2021-09-13        1
# 2016-03-11        1
# 2020-03-29        1
# 2019-10-04        1
# Name: Last Scraped Date, Length: 1918, dtype: int64
# Colombia    46624
# Name: Country, dtype: int64
# 4.680000    64
# 4.648000    61
# 4.640000    58
# 4.642000    48
# 4.643000    48
#             ..
# 4.673042     1
# 4.694191     1
# 4.609429     1
# 4.702448     1
# 4.659162     1
# Name: Latitude, Length: 26055, dtype: int64
# -74.072000    105
# -74.070000     99
# -74.062000     98
# -74.057000     91
# -74.068000     89
#              ...
# -74.045294      1
# -74.056595      1
# -74.065239      1
# -74.046705      1
# -74.118455      1
# Name: Longitude, Length: 22510, dtype: int64
# Bogotá    46624
# Name: City, dtype: int64
# Chapinero         10885
# Usaquen            8851
# Teusaquillo        6492
# Suba               5939
# Santa Fe           4132
# Engativa           2746
# Fontibon           2170
# Barrios Unidos     2154
# Kennedy            1437
# Puente Aranda       538
# Los Martires        475
# San Cristobal       232
# Antonio Narino      160
# Bosa                158
# Rafael Uribe        156
# Tunjuelito           99
# Name: Neighborhood, dtype: int64
# COP    31449
# USD    14226
# EUR      795
# GBP       67
# AUD       15
# CAD       14
# CLP       11
# ARS        7
# SEK        6
# CRC        4
# MXN        4
# CZK        3
# BRL        3
# CNY        3
# PEN        3
# DKK        2
# CHF        2
# PHP        1
# TWD        1
# VND        1
# HKD        1
# THB        1
# SGD        1
# HUF        1
# NZD        1
# NOK        1
# AED        1
# Name: Currency Native, dtype: int64
# 10.00    476
# 11.00    136
# 12.00    132
# 13.00    122
# 20.00    117
#         ...
# 54.58      1
# 43.62      1
# 74.36      1
# 26.72      1
# 30.48      1
# Name: Average Daily Rate (USD), Length: 4673, dtype: int64
# 40000.00     142
# 50000.00     135
# 60000.00     120
# 45000.00      90
# 100000.00     79
#             ...
# 139319.97      1
# 169617.20      1
# 44162.00       1
# 56930.97       1
# 151233.10      1
# Name: Average Daily Rate (Native), Length: 9333, dtype: int64
# 0.0       34128
# 10.0         77
# 20.0         72
# 60.0         66
# 30.0         64
#           ...
# 4665.0        1
# 4802.0        1
# 2478.0        1
# 5716.0        1
# 5060.0        1
# Name: Annual Revenue LTM (USD), Length: 4077, dtype: int64
# 0.0           34132
# 120000.0         36
# 600000.0         35
# 400000.0         31
# 40000.0          31
#               ...
# 511845.0          1
# 3500334.0         1
# 538816.0          1
# 465.0             1
# 18299206.0        1
# Name: Annual Revenue LTM (Native), Length: 9635, dtype: int64
# 0.032    409
# 1.000    230
# 0.065    222
# 0.194    191
# 0.033    187
#         ...
# 0.334      1
# 0.854      1
# 0.907      1
# 0.166      1
# 0.850      1
# Name: Occupancy Rate LTM, Length: 939, dtype: int64
# 0.0      33092
# 1.0       2377
# 2.0       1378
# 3.0       1030
# 4.0        839
#          ...
# 145.0        1
# 176.0        1
# 118.0        1
# 103.0        1
# 142.0        1
# Name: Number of Bookings LTM, Length: 134, dtype: int64
# 1.0      723
# 2.0      484
# 3.0      471
# 6.0      435
# 5.0      359
#         ...
# 260.0      1
# 285.0      1
# 244.0      1
# 314.0      1
# 262.0      1
# Name: Count Reservation Days LTM, Length: 296, dtype: int64
# 30.0     462
# 29.0     376
# 27.0     336
# 25.0     299
# 28.0     285
#         ...
# 305.0      1
# 306.0      1
# 265.0      1
# 251.0      1
# 300.0      1
# Name: Count Available Days LTM, Length: 299, dtype: int64
# 0.0      4893
# 1.0       456
# 2.0       325
# 3.0       240
# 4.0       201
#          ...
# 175.0       1
# 179.0       1
# 193.0       1
# 219.0       1
# 212.0       1
# Name: Count Blocked Days LTM, Length: 206, dtype: int64
# 1.0     32007
# 2.0      7647
# 3.0      3440
# 0.0      2141
# 4.0       665
# 5.0       191
# 10.0      130
# 6.0        91
# 7.0        67
# 9.0        35
# 8.0        34
# 12.0       25
# 20.0       21
# 15.0       21
# 13.0       15
# 16.0       13
# 11.0       11
# 14.0        9
# 50.0        6
# 18.0        5
# 19.0        4
# 27.0        4
# 28.0        4
# 32.0        4
# 22.0        4
# 25.0        4
# 30.0        3
# 17.0        3
# 23.0        3
# 35.0        3
# 26.0        2
# 36.0        2
# 40.0        2
# 21.0        2
# 33.0        1
# 34.0        1
# 47.0        1
# 38.0        1
# 29.0        1
# 49.0        1
# Name: Bedrooms, dtype: int64
# 1.0     29804
# 2.0      8264
# 1.5      3665
# 2.5      1534
# 3.0      1358
# 0.0       434
# 3.5       372
# 4.0       351
# 5.0       144
# 4.5       122
# 8.0       101
# 0.5        86
# 6.0        82
# 10.0       52
# 7.0        45
# 5.5        35
# 12.0       30
# 9.0        14
# 8.5        14
# 6.5        14
# 15.0       11
# 11.0       10
# 20.0        9
# 16.0        9
# 17.0        7
# 13.0        7
# 18.0        6
# 10.5        4
# 35.0        3
# 13.5        3
# 28.0        3
# 7.5         3
# 23.0        3
# 32.0        3
# 29.5        2
# 22.0        2
# 27.0        2
# 9.5         2
# 20.5        1
# 50.0        1
# 26.5        1
# 14.0        1
# 21.0        1
# 37.0        1
# 45.0        1
# 25.0        1
# 11.5        1
# 31.0        1
# 19.5        1
# 12.5        1
# 42.0        1
# 25.5        1
# Name: Bathrooms, dtype: int64
# 2.0     18880
# 1.0      9855
# 4.0      7203
# 3.0      4959
# 5.0      1936
# 6.0      1865
# 8.0       511
# 16.0      393
# 7.0       378
# 10.0      251
# 12.0      127
# 9.0       108
# 15.0       63
# 14.0       49
# 11.0       23
# 13.0       23
# Name: Max Guests, dtype: int64
# 2019-08-30    504
# 2019-08-29    373
# 2019-08-31    329
# 2019-08-21    272
# 2019-08-28    254
#              ...
# 2013-12-19      1
# 2014-01-06      1
# 2015-12-25      1
# 2014-11-26      1
# 2014-09-26      1
# Name: Calendar Last Updated, Length: 1771, dtype: int64
# 100.0    22301
# 0.0       8690
# 50.0      1325
# 90.0       685
# 80.0       585
#          ...
# 18.0         1
# 15.0         1
# 24.0         1
# 23.0         1
# 72.0         1
# Name: Response Rate, Length: 86, dtype: int64
# False    43922
# True      2702
# Name: Airbnb Superhost, dtype: int64
# flexible                                                21400
# moderate                                                 5076
# strict_14_with_grace_period                              4594
# Flexible - Free cancellation for 48 hours                3898
# Flexible                                                 3455
# Free cancellation for 48 hours                           1596
# Flexible · Free cancellation for 48 hours                1329
# Moderate - Free cancellation for 48 hours                 782
# Flexible · Free cancellation for 48 hours.                719
# Moderate                                                  653
# Strict                                                    513
# Flexible policy –  Free cancellation within 48 hours      513
# Strict - Free cancellation for 48 hours                   463
# strict                                                    450
# firm                                                      355
# Moderate · Free cancellation for 48 hours                 218
# Strict · Free cancellation for 48 hours                   182
# Moderate · Free cancellation for 48 hours.                109
# Moderate policy –  Free cancellation within 48 hours      103
# Strict policy  –  Free cancellation within 48 hours        60
# Strict · Free cancellation for 48 hours.                   55
# super_strict_60                                            42
# Super Strict 60 Days                                       16
# super_strict_30                                            12
# better_strict                                               8
# Super Strict 30 days                                        8
# Super Strict 60 days                                        7
# firm_30_strict                                              3
# Super Strict 30                                             2
# Super Strict 60                                             2
# Super Strict 30 Days                                        1
# Name: Cancellation Policy, dtype: int64
# 100.0     739
# 103.0     401
# 200.0     340
# 150.0     227
# 206.0     215
#          ...
# 84.0        1
# 670.0       1
# 5150.0      1
# 5253.0      1
# 1569.0      1
# Name: Security Deposit (USD), Length: 387, dtype: int64
# 100.0        693
# 103.0        375
# 200.0        319
# 300000.0     287
# 500000.0     272
#             ...
# 201.0          1
# 1466990.0      1
# 623.0          1
# 745.0          1
# 281700.0       1
# Name: Security Deposit (Native), Length: 502, dtype: int64
# 8.0      2012
# 5.0      1823
# 15.0     1659
# 10.0     1595
# 13.0     1427
#          ...
# 2.0         1
# 198.0       1
# 83.0        1
# 382.0       1
# 81.0        1
# Name: Cleaning Fee (USD), Length: 119, dtype: int64
# 15.0       1058
# 10.0       1033
# 20.0        864
# 5.0         663
# 50000.0     632
#            ...
# 140.0         1
# 27230.0       1
# 88019.0       1
# 40402.0       1
# 14307.0       1
# Name: Cleaning Fee (Native), Length: 490, dtype: int64
# 10.0     1769
# 5.0      1490
# 6.0       819
# 15.0      629
# 8.0       611
#          ...
# 150.0       1
# 98.0        1
# 1.0         1
# 120.0       1
# 96.0        1
# Name: Extra People Fee (USD), Length: 86, dtype: int64
# 10.0       1259
# 5.0         727
# 20000.0     646
# 30000.0     591
# 15.0        577
#            ...
# 20023.0       1
# 17551.0       1
# 55.0          1
# 71861.0       1
# 14550.0       1
# Name: Extra People Fee (Native), Length: 512, dtype: int64
# 10.0     5396
# 15.0     2017
# 13.0     1755
# 11.0     1592
# 20.0     1524
#          ...
# 345.0       1
# 550.0       1
# 365.0       1
# 457.0       1
# 950.0       1
# Name: Published Nightly Rate (USD), Length: 520, dtype: int64
# 840.0      338
# 420.0      320
# 560.0      319
# 280.0      308
# 700.0      301
#           ...
# 4400.0       1
# 3424.0       1
# 2790.0       1
# 15978.0      1
# 3178.0       1
# Name: Published Monthly Rate (USD), Length: 2855, dtype: int64
# 70.0      455
# 210.0     368
# 72.0      363
# 140.0     359
# 105.0     353
#          ...
# 1736.0      1
# 1463.0      1
# 1596.0      1
# 931.0       1
# 1990.0      1
# Name: Published Weekly Rate (USD), Length: 1308, dtype: int64
# After 3:00 PM         9852
# Flexible              9637
# After 3PM             3529
# Anytime after 3PM     1363
# After 2:00 PM         1189
#                       ...
# 4:00 AM                  1
# After 2:00 AM            1
# 7:00 PM                  1
# 9PM - 9PM                1
# Anytime after 11PM       1
# Name: Check-in Time, Length: 380, dtype: int64
# 11:00 AM               4968
# 12:00 PM               4717
# 12PM (noon)            2198
# 1:00 PM                1857
# 11AM                   1072
# 1PM                    1016
# 3:00 PM                 975
# 10:00 AM                904
# 2:00 PM                 786
# 3PM                     598
# 2PM                     490
# 12AM (midnight)         416
# 12:00 AM                386
# 10AM                    316
# 4:00 PM                 284
# 5:00 PM                 281
# 6:00 PM                 257
# 3:00 AM                 218
# 5PM                     197
# 4PM                     191
# 6PM                     185
# 1:00 AM                 178
# 2:00 AM                 146
# 3AM                     140
# 8:00 PM                 126
# 9:00 AM                 121
# 8PM                     117
# 1AM                     105
# 11:00 PM                102
# 7:00 PM                  87
# 8:00 AM                  82
# 2AM                      81
# 11PM                     75
# 12:00 PM (noon)          73
# 4:00 AM                  73
# 7PM                      66
# 5:00 AM                  65
# 10:00 PM                 65
# 9AM                      64
# 8AM                      56
# 9:00 PM                  54
# 6:00 AM                  47
# 9PM                      38
# 10PM                     38
# 4AM                      35
# 5AM                      31
# 7:00 AM                  31
# 7AM                      27
# 6AM                      21
# 12:00 AM (midnight)       1
# Flexible                  1
# Name: Checkout Time, dtype: int64
# 1.0      26066
# 2.0       7268
# 3.0       4406
# 30.0      1654
# 5.0       1557
#          ...
# 170.0        1
# 569.0        1
# 58.0         1
# 160.0        1
# 91.0         1
# Name: Minimum Stay, Length: 89, dtype: int64
# 0.0      24468
# 1.0       6211
# 2.0       3000
# 3.0       1840
# 4.0       1305
#          ...
# 240.0        1
# 258.0        1
# 362.0        1
# 296.0        1
# 207.0        1
# Name: Number of Reviews, Length: 248, dtype: int64
# 7.0      3131
# 8.0      3124
# 6.0      2955
# 9.0      2880
# 5.0      2687
#          ...
# 151.0       1
# 154.0       1
# 158.0       1
# 198.0       1
# 186.0       1
# Name: Number of Photos, Length: 155, dtype: int64
# True     26110
# False    20514
# Name: Instantbook Enabled, dtype: int64
# 5.0    9307
# 4.8    2864
# 4.5    1596
# 4.7    1518
# 4.0    1377
# 4.9    1055
# 3.0     510
# 4.3     500
# 4.2     434
# 1.0     434
# 4.6     412
# 4.4     250
# 3.5     187
# 2.0     178
# 3.6     155
# 3.8      97
# 3.4      66
# 3.9      57
# 2.5      52
# 4.1      47
# 3.2      18
# 2.6      18
# 2.4      13
# 3.7       9
# 3.1       8
# 1.5       7
# 2.8       5
# 3.3       4
# 2.2       3
# 2.9       1
# 1.6       1
# Name: Overall Rating, dtype: int64
# 44018885.0    1
# 37399094.0    1
# 37414617.0    1
# 37415637.0    1
# 37421063.0    1
#              ..
# 31389901.0    1
# 31390095.0    1
# 31390977.0    1
# 31391312.0    1
# 23918318.0    1
# Name: Airbnb Property ID, Length: 46624, dtype: int64
# 5052218.0      343
# 296581687.0    312
# 213524223.0    296
# 267819123.0    237
# 48225748.0     196
#               ...
# 14992481.0       1
# 14983585.0       1
# 12967420.0       1
# 14842345.0       1
# 179780077.0      1
# Name: Airbnb Host ID, Length: 28065, dtype: int64
# https://www.airbnb.com/rooms/44018885    1
# https://www.airbnb.com/rooms/37399094    1
# https://www.airbnb.com/rooms/37414617    1
# https://www.airbnb.com/rooms/37415637    1
# https://www.airbnb.com/rooms/37421063    1
#                                         ..
# https://www.airbnb.com/rooms/31389901    1
# https://www.airbnb.com/rooms/31390095    1
# https://www.airbnb.com/rooms/31390977    1
# https://www.airbnb.com/rooms/31391312    1
# https://www.airbnb.com/rooms/23918318    1
# Name: Airbnb Listing URL, Length: 46624, dtype: int64
# https://a0.muscache.com/im/pictures/7de34810-5412-41f5-978c-bb100ec58d11.jpg?aki_policy=x_large    90
# https://a0.muscache.com/im/pictures/498b62ad-2375-4f4e-a1b7-f7abcd90a7c0.jpg?aki_policy=x_large    24
# https://a0.muscache.com/im/pictures/40e8ad02-69a4-44b5-beb6-58013d08e780.jpg?aki_policy=x_large    13
# https://a0.muscache.com/im/pictures/4186dbbc-fea5-4818-ac4f-a628980f0640.jpg?aki_policy=x_large    12
# https://a0.muscache.com/im/pictures/d561ccb8-2d89-45b5-aaa5-9d08f4168f41.jpg?aki_policy=x_large    10
#                                                                                                    ..
# https://a0.muscache.com/im/pictures/6cf25077-4e24-45c6-a963-ac54e21579e4.jpg?aki_policy=x_large     1
# https://a0.muscache.com/im/pictures/dfafed74-69a5-4338-8e04-93356c400d80.jpg?aki_policy=x_large     1
# https://a0.muscache.com/im/pictures/cc499dfb-2481-40bb-aebb-41f57374c396.jpg?aki_policy=x_large     1
# https://a0.muscache.com/im/pictures/65e34412-ec9a-4732-a084-48b754cdbdd9.jpg?aki_policy=x_large     1
# https://a0.muscache.com/im/pictures/7b170cfc-875f-4510-85f5-4cc2f61e47c4.jpg?aki_policy=x_large     1
# Name: Airbnb Listing Main Image URL, Length: 45077, dtype: int64
